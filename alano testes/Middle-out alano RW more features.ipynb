# %% [markdown]
# # Siemens Advanta- Bussines Case Project 2025/2026
#
# **Project developed by Group V**:
#    - Alano Gonçalves (20250457)
#    - Catarina Martins (20221914)
#    - João Carichas (20250507)
#    - Marta Ribeiro (20221886)
#    - Nicole Nogueira(20221961)

# %% [markdown]
# ## 1. Import the needed libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from math import ceil
import zipfile
import xml.etree.ElementTree as ET
from statsmodels.tsa.seasonal import seasonal_decompose
import plotly.express as px

from collections import Counter
from sklearn.feature_selection import mutual_info_regression
from sklearn.inspection import permutation_importance
from sklearn.metrics import mean_absolute_error, mean_squared_error, root_mean_squared_error
from catboost import (CatBoostRegressor,Pool,EFeaturesSelectionAlgorithm)
import shap
from support import *
from itertools import product
from prophet import Prophet

# %% [markdown]
# ## 2. Data importation

# %%
SALES_PATH  = 'Case2_data_extract_share.xlsx'
MARKET_PATH = 'Case2_market_data_share.xlsx'
train_data = read_sales_sheet(SALES_PATH, 'xl/worksheets/sheet1.xml')
test_data = read_sales_sheet(SALES_PATH, 'xl/worksheets/sheet3.xml')

# %%
df_market = pd.read_excel(MARKET_PATH, sheet_name='Sheet1')
df_period_map = pd.read_excel(MARKET_PATH, sheet_name='Sheet2')

# %% [markdown]
# ## 3. Data exploration and understanding

# %% [markdown]
# ### 3.1. Changing Names and Datatypes

# %%
#overview the dataset
train_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4237 entries, 0 to 4236
# Data columns (total 7 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Anon Period              4237 non-null   object
#  1   TGL Biz Desc             4237 non-null   object
#  2   TGL Business Unit        4237 non-null   object
#  3   TGL Business Segment     4237 non-null   object
#  4   TGL Business Subsegment  4237 non-null   object
#  5   Orders cons. (anon)      4237 non-null   object
#  6   Revenue cons. (anon)     4237 non-null   object
# dtypes: object(7)
# memory usage: 231.8+ KB

# %% [markdown]
# - At first sight, the training dataset has no missing values and have 4237 rows.
# - The datatypes, are not correct so we will have to fix them.

# %%
#changing the name of the variables do it is easy to track them
train_data = train_data.rename(columns={
    'Anon Period': 'Period',
    'TGL Biz Desc': 'Biz_Desc',
    'TGL Business Unit': 'Business_Unit',
    'TGL Business Segment': 'Segment',
    'TGL Business Subsegment': 'Subsegment',
    'Orders cons. (anon)': 'Orders',
    'Revenue cons. (anon)': 'Revenue'
})

# %%
#changing the datatypes so it is possible to visualize the data
train_data['Period'] = train_data['Period'].round().astype('Int32')
train_data['Orders'] = train_data['Orders'].round().astype('Int32')
train_data['Revenue'] = train_data['Revenue'].round().astype('Int32')

# %% [markdown]
# ### 3.2. Data Overview

# %%
#overview the dataset
train_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4237 entries, 0 to 4236
# Data columns (total 7 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Period         4237 non-null   Int32
#  1   Biz_Desc       4237 non-null   object
#  2   Business_Unit  4237 non-null   object
#  3   Segment        4237 non-null   object
#  4   Subsegment     4237 non-null   object
#  5   Orders         4237 non-null   Int32
#  6   Revenue        4237 non-null   Int32
# dtypes: Int32(3), object(4)
# memory usage: 194.6+ KB

# %%
df_market.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 180 entries, 0 to 179
# Data columns (total 78 columns):
#  #   Column                                    Non-Null Count  Dtype
# ---  ------                                    --------------  -----
#  0   Period                                    180 non-null    int64
#  1   China_Core_Inflation_Rate                 178 non-null    float64
#  2   China_Exports                             178 non-null    float64
#  3   China_GDP                                 15 non-null     float64
#  4   China_GDP_from_Construction               60 non-null     float64
#  5   China_GDP_from_Manufacturing              60 non-null     float64
#  6   China_Industrial_Production               176 non-null    float64
#  7   China_Industrial_Production_Mom           170 non-null    float64
#  8   China_Inflation_Rate                      178 non-null    float64
#  9   China_Interest_Rate                       137 non-null    float64
#  10  China_Steel_Production                    180 non-null    int64
#  11  France_Core_Inflation_Rate                178 non-null    float64
#  12  France_Exports                            178 non-null    float64
#  13  France_GDP                                15 non-null     float64
#  14  France_GDP_from_Construction              60 non-null     float64
#  15  France_GDP_from_Manufacturing             60 non-null     float64
#  16  France_Industrial_Production              178 non-null    float64
#  17  France_Industrial_Production_Mom          178 non-null    float64
#  18  France_Inflation_Rate                     178 non-null    float64
#  19  France_Interest_Rate                      176 non-null    float64
#  20  France_Steel_Production                   129 non-null    float64
#  21  Germany_Core_Inflation_Rate               178 non-null    float64
#  22  Germany_Exports                           178 non-null    float64
#  23  Germany_GDP                               15 non-null     float64
#  24  Germany_GDP_from_Construction             60 non-null     float64
#  25  Germany_GDP_from_Manufacturing            60 non-null     float64
#  26  Germany_Industrial_Production             178 non-null    float64
#  27  Germany_Industrial_Production_Mom         178 non-null    float64
#  28  Germany_Inflation_Rate                    178 non-null    float64
#  29  Germany_Interest_Rate                     176 non-null    float64
#  30  Germany_Steel_Production                  180 non-null    float64
#  31  Italy_Core_Inflation_Rate                 178 non-null    float64
#  32  Italy_Exports                             178 non-null    float64
#  33  Italy_GDP                                 15 non-null     float64
#  34  Italy_GDP_from_Construction               60 non-null     float64
#  35  Italy_GDP_from_Manufacturing              60 non-null     float64
#  36  Italy_Industrial_Production               178 non-null    float64
#  37  Italy_Industrial_Production_Mom           178 non-null    float64
#  38  Italy_Inflation_Rate                      178 non-null    float64
#  39  Italy_Interest_Rate                       176 non-null    float64
#  40  Italy_Steel_Production                    129 non-null    float64
#  41  Japan_Core_Inflation_Rate                 178 non-null    float64
#  42  Japan_Exports                             178 non-null    float64
#  43  Japan_GDP                                 15 non-null     float64
#  44  Japan_GDP_from_Construction               15 non-null     float64
#  45  Japan_GDP_from_Manufacturing              15 non-null     float64
#  46  Japan_Industrial_Production               178 non-null    float64
#  47  Japan_Industrial_Production_Mom           178 non-null    float64
#  48  Japan_Inflation_Rate                      178 non-null    float64
#  49  Japan_Interest_Rate                       176 non-null    float64
#  50  Japan_Steel_Production                    180 non-null    float64
#  51  Switzerland_Core_Inflation_Rate           178 non-null    float64
#  52  Switzerland_Exports                       178 non-null    float64
#  53  Switzerland_GDP                           15 non-null     float64
#  54  Switzerland_Industrial_Production         60 non-null     float64
#  55  Switzerland_Industrial_Production_Mom     60 non-null     float64
#  56  Switzerland_Inflation_Rate                178 non-null    float64
#  57  Switzerland_Interest_Rate                 176 non-null    float64
#  58  United_Kingdom_Core_Inflation_Rate        178 non-null    float64
#  59  United_Kingdom_Exports                    178 non-null    float64
#  60  United_Kingdom_GDP                        15 non-null     float64
#  61  United_Kingdom_GDP_from_Construction      60 non-null     float64
#  62  United_Kingdom_GDP_from_Manufacturing     60 non-null     float64
#  63  United_Kingdom_Industrial_Production      178 non-null    float64
#  64  United_Kingdom_Industrial_Production_Mom  178 non-null    float64
#  65  United_Kingdom_Inflation_Rate             178 non-null    float64
#  66  United_Kingdom_Interest_Rate              176 non-null    float64
#  67  United_Kingdom_Steel_Production           129 non-null    float64
#  68  United_States_Core_Inflation_Rate         178 non-null    float64
#  69  United_States_Exports                     178 non-null    float64
#  70  United_States_GDP                         15 non-null     float64
#  71  United_States_GDP_from_Construction       60 non-null     float64
#  72  United_States_GDP_from_Manufacturing      60 non-null     float64
#  73  United_States_Industrial_Production       178 non-null    float64
#  74  United_States_Industrial_Production_Mom   178 non-null    float64
#  75  United_States_Inflation_Rate              178 non-null    float64
#  76  United_States_Interest_Rate               175 non-null    float64
#  77  United_States_Steel_Production            180 non-null    float64
# dtypes: float64(76), int64(2)
# memory usage: 109.8 KB

# %% [markdown]
# - Considering that the total number of rows is 180 (corresponding to the number of years), most of the columns have a considerable amount of missing values.

# %%
#first 20 rows
train_data.head(20)
# Out:
#     Period Biz_Desc Business_Unit   Segment Subsegment  Orders  Revenue
# 0        1      SSI        SSI027  SSI02710   SSI02710       0  -390277
# 1        2      SSI        SSI027  SSI02710   SSI02710       0      334
# 2        3      SSI        SSI027  SSI02710   SSI02710       0      334
# 3        4      SSI        SSI027  SSI02710   SSI02710       0  1811758
# 4        5      SSI        SSI027  SSI02710   SSI02710       0    80112
# 5        6      SSI        SSI027  SSI02710   SSI02710       0    38468
# 6        7      SSI        SSI027  SSI02710   SSI02710       0      334
# 7        8      SSI        SSI027  SSI02710   SSI02710       0      334
# 8        9      SSI        SSI027  SSI02710   SSI02710       0   -37173
# 9       10      SSI        SSI027  SSI02710   SSI02710       0    38094
# 10      11      SSI        SSI027  SSI02710   SSI02710       0      334
# 11      12      SSI        SSI027  SSI02710   SSI02710       0      334
# 12      13      SSI        SSI027  SSI02710   SSI02710       0      334
# 13      14      SSI        SSI027  SSI02710   SSI02710       0      334
# 14      15      SSI        SSI027  SSI02710   SSI02710       0      334
# 15      16      SSI        SSI027  SSI02710   SSI02710       0      334
# 16      17      SSI        SSI027  SSI02710   SSI02710       0      334
# 17      18      SSI        SSI027  SSI02710   SSI02710       0      334
# 18      19      SSI        SSI027  SSI02710   SSI02710       0      334
# 19      20      SSI        SSI027  SSI02710   SSI02710       0      334

# %%
#first 20 rows
df_market.head(20)
# Out:
#     Period  China_Core_Inflation_Rate  China_Exports  China_GDP  \
# 0     -131                        NaN            NaN        NaN
# 1     -130                        NaN            NaN        NaN
# 2     -129                        1.0         137.35        NaN
# 3     -128                        1.1         145.45        NaN
# 4     -127                        1.1         139.26        NaN
# 5     -126                        1.1         144.99        NaN
# 6     -125                        1.3         135.96        NaN
# 7     -124                        1.5         153.29        NaN
# 8     -123                        1.7         154.14    6192.56
# 9     -122                        2.3         150.70        NaN
# 10    -121                        2.0          96.68        NaN
# 11    -120                        2.3         152.13        NaN
# 12    -119                        2.3         155.59        NaN
# 13    -118                        2.4         157.05        NaN
# 14    -117                        2.5         161.90        NaN
# 15    -116                        2.4         175.15        NaN
# 16    -115                        2.5         173.24        NaN
# 17    -114                        2.4         169.58        NaN
# 18    -113                        2.3         157.35        NaN
# 19    -112                        1.9         174.39        NaN
#
#     China_GDP_from_Construction  China_GDP_from_Manufacturing  \
# 0                           NaN                           NaN
# 1                           NaN                           NaN
# 2                       10710.5                       76425.9
# 3                           NaN                           NaN
# 4                           NaN                           NaN
# 5                       18012.5                      118221.6
# 6                           NaN                           NaN
# 7                           NaN                           NaN
# 8                       27259.3                      165123.1
# 9                           NaN                           NaN
# 10                          NaN                           NaN
# 11                       4749.0                       42670.3
# 12                          NaN                           NaN
# 13                          NaN                           NaN
# 14                      12927.0                       91634.9
# 15                          NaN                           NaN
# 16                          NaN                           NaN
# 17                      21897.4                      141550.7
# 18                          NaN                           NaN
# 19                          NaN                           NaN
#
#     China_Industrial_Production  China_Industrial_Production_Mom  \
# 0                           NaN                              NaN
# 1                           NaN                              NaN
# 2                         13.70                              NaN
# 3                         13.40                              NaN
# 4                         13.90                              NaN
# 5                         13.30                              NaN
# 6                         13.10                              NaN
# 7                         13.30                              NaN
# 8                         13.50                              NaN
# 9                         13.41                              NaN
# 10                        14.90                             0.93
# 11                        14.80                             0.99
# 12                        13.40                             1.32
# 13                        13.30                             0.79
# 14                        15.10                             1.30
# 15                        14.00                             0.82
# 16                        13.50                             0.85
# 17                        13.80                             0.95
# 18                        13.20                             0.71
# 19                        12.40                             0.68
#
#     China_Inflation_Rate  China_Interest_Rate  ...  \
# 0                    NaN                  NaN  ...
# 1                    NaN                  NaN  ...
# 2                    2.9                  NaN  ...
# 3                    3.3                  NaN  ...
# 4                    3.5                  NaN  ...
# 5                    3.6                  NaN  ...
# 6                    4.4                  NaN  ...
# 7                    5.1                  NaN  ...
# 8                    4.6                  NaN  ...
# 9                    4.9                  NaN  ...
# 10                   4.9                  NaN  ...
# 11                   5.4                  NaN  ...
# 12                   5.3                  NaN  ...
# 13                   5.5                  NaN  ...
# 14                   6.4                  NaN  ...
# 15                   6.5                  NaN  ...
# 16                   6.2                  NaN  ...
# 17                   6.1                  NaN  ...
# 18                   5.5                  NaN  ...
# 19                   4.2                  NaN  ...
#
#     United_States_Core_Inflation_Rate  United_States_Exports  \
# 0                                 NaN                    NaN
# 1                                 NaN                    NaN
# 2                                 0.9                153.326
# 3                                 0.9                156.763
# 4                                 0.9                157.769
# 5                                 0.8                158.624
# 6                                 0.6                164.234
# 7                                 0.8                165.621
# 8                                 0.8                168.510
# 9                                 1.0                169.897
# 10                                1.1                168.665
# 11                                1.2                176.676
# 12                                1.3                178.839
# 13                                1.5                178.856
# 14                                1.6                176.894
# 15                                1.8                181.502
# 16                                2.0                182.475
# 17                                2.0                183.858
# 18                                2.1                182.681
# 19                                2.2                180.797
#
#     United_States_GDP  United_States_GDP_from_Construction  \
# 0                 NaN                                  NaN
# 1                 NaN                                  NaN
# 2                 NaN                                554.4
# 3                 NaN                                  NaN
# 4                 NaN                                  NaN
# 5                 NaN                                549.2
# 6                 NaN                                  NaN
# 7                 NaN                                  NaN
# 8            15048.97                                545.1
# 9                 NaN                                  NaN
# 10                NaN                                  NaN
# 11                NaN                                533.2
# 12                NaN                                  NaN
# 13                NaN                                  NaN
# 14                NaN                                541.5
# 15                NaN                                  NaN
# 16                NaN                                  NaN
# 17                NaN                                542.3
# 18                NaN                                  NaN
# 19                NaN                                  NaN
#
#     United_States_GDP_from_Manufacturing  United_States_Industrial_Production  \
# 0                                    NaN                                  NaN
# 1                                    NaN                                  NaN
# 2                                 1925.9                                  8.5
# 3                                    NaN                                  7.7
# 4                                    NaN                                  6.9
# 5                                 1947.4                                  6.3
# 6                                    NaN                                  5.7
# 7                                    NaN                                  5.4
# 8                                 1957.6                                  6.1
# 9                                    NaN                                  4.7
# 10                                   NaN                                  3.9
# 11                                1942.1                                  4.3
# 12                                   NaN                                  3.5
# 13                                   NaN                                  2.3
# 14                                1955.7                                  2.3
# 15                                   NaN                                  2.4
# 16                                   NaN                                  2.7
# 17                                1932.5                                  2.3
# 18                                   NaN                                  3.3
# 19                                   NaN                                  3.2
#
#     United_States_Industrial_Production_Mom  United_States_Inflation_Rate  \
# 0                                       NaN                           NaN
# 1                                       NaN                           NaN
# 2                                       0.2                           1.1
# 3                                       0.4                           1.2
# 4                                       0.4                           1.1
# 5                                       0.3                           1.1
# 6                                      -0.3                           1.2
# 7                                       0.1                           1.1
# 8                                       1.0                           1.5
# 9                                      -0.2                           1.6
# 10                                     -0.4                           2.1
# 11                                      1.0                           2.7
# 12                                     -0.3                           3.2
# 13                                      0.1                           3.6
# 14                                      0.3                           3.6
# 15                                      0.5                           3.6
# 16                                      0.6                           3.8
# 17                                     -0.1                           3.9
# 18                                      0.7                           3.5
# 19                                      0.0                           3.4
#
#     United_States_Interest_Rate  United_States_Steel_Production
# 0                           NaN                         6955.00
# 1                           NaN                         7264.00
# 2                           NaN                         7090.00
# 3                          0.25                         6764.00
# 4                          0.25                         6619.00
# 5                          0.25                         6605.00
# 6                          0.25                         6543.00
# 7                          0.25                         6418.00
# 8                          0.25                         6648.00
# 9                          0.25                         7191.38
# 10                         0.25                         6689.54
# 11                         0.25                         7367.54
# 12                         0.25                         7051.00
# 13                         0.25                         7141.38
# 14                         0.25                         7245.54
# 15                         0.25                         7368.46
# 16                         0.25                         7437.65
# 17                         0.25                         7233.03
# 18                         0.25                         7155.69
# 19                         0.25                         7032.16
#
# [20 rows x 78 columns]

# %%
#descriptive statistics for numerical data
train_data.describe()
# Out:
#           Period           Orders          Revenue
# count     4237.0           4237.0           4237.0
# mean   22.510031  40076623.578475  35976412.567855
# std    12.238664  70414862.658063  63786043.938389
# min          1.0      -56101878.0      -12010755.0
# 25%         12.0         871389.0        1020192.0
# 50%         23.0        9281978.0        8850535.0
# 75%         33.0       43312847.0       36460128.0
# max         42.0      595094385.0      420036087.0

# %% [markdown]
# - The dataset has 42 months.
# - There are rows in *Orders* and *Revenue* that are negative- Is it possible?

# %%
#descriptive statistics for numerical data
df_market.describe().round(2)
# Out:
#        Period  China_Core_Inflation_Rate  China_Exports  China_GDP  \
# count  180.00                     178.00         178.00      15.00
# mean   -41.50                       1.37         215.89   13031.13
# std     52.11                       0.60          56.05    4130.32
# min   -131.00                      -0.30          80.38    6192.56
# 25%    -86.25                       0.90         177.79   10208.83
# 50%    -41.50                       1.50         204.65   12537.56
# 75%      3.25                       1.80         263.34   16599.06
# max     48.00                       2.50         339.66   18743.80
#
#        China_GDP_from_Construction  China_GDP_from_Manufacturing  \
# count                        60.00                         60.00
# mean                      33122.37                     173068.40
# std                       22602.81                      96035.07
# min                        4749.00                      42670.30
# 25%                       13793.25                      93960.05
# 50%                       28693.25                     163199.35
# 75%                       47756.28                     227774.98
# max                       88862.80                     404518.50
#
#        China_Industrial_Production  China_Industrial_Production_Mom  \
# count                       176.00                           170.00
# mean                          7.42                             0.65
# std                           5.04                             3.29
# min                         -13.50                           -22.10
# 25%                           5.40                             0.44
# 50%                           6.30                             0.55
# 75%                           9.05                             0.76
# max                          35.10                            36.56
#
#        China_Inflation_Rate  China_Interest_Rate  ...  \
# count                178.00               137.00  ...
# mean                   2.08                 4.21  ...
# std                    1.49                 0.69  ...
# min                   -0.80                 3.10  ...
# 25%                    1.30                 3.70  ...
# 50%                    2.00                 4.30  ...
# 75%                    2.70                 4.31  ...
# max                    6.50                 5.77  ...
#
#        United_States_Core_Inflation_Rate  United_States_Exports  \
# count                             178.00                 178.00
# mean                                2.59                 209.07
# std                                 1.40                  31.90
# min                                 0.60                 147.14
# 25%                                 1.70                 188.11
# 50%                                 2.10                 198.92
# 75%                                 3.18                 215.55
# max                                 6.60                 283.27
#
#        United_States_GDP  United_States_GDP_from_Construction  \
# count              15.00                                60.00
# mean            20549.85                               719.75
# std              4404.15                               143.70
# min             15048.97                               533.20
# 25%             17244.41                               572.33
# 50%             19612.10                               654.10
# 75%             22610.57                               867.68
# max             29184.89                               904.40
#
#        United_States_GDP_from_Manufacturing  \
# count                                 60.00
# mean                                2129.46
# std                                  148.43
# min                                 1906.30
# 25%                                 2000.15
# 50%                                 2104.35
# 75%                                 2251.68
# max                                 2389.00
#
#        United_States_Industrial_Production  \
# count                               178.00
# mean                                  1.03
# std                                   3.86
# min                                 -17.20
# 25%                                  -0.98
# 50%                                   1.60
# 75%                                   3.18
# max                                  16.10
#
#        United_States_Industrial_Production_Mom  United_States_Inflation_Rate  \
# count                                   178.00                        178.00
# mean                                      0.07                          2.60
# std                                       1.33                          1.98
# min                                     -13.20                         -0.20
# 25%                                      -0.28                          1.42
# 50%                                       0.10                          2.10
# 75%                                       0.50                          3.08
# max                                       6.60                          9.10
#
#        United_States_Interest_Rate  United_States_Steel_Production
# count                       175.00                          180.00
# mean                          1.43                         6908.79
# std                           1.75                          529.05
# min                           0.25                         4746.00
# 25%                           0.25                         6648.25
# 50%                           0.25                         6955.50
# 75%                           2.00                         7270.16
# max                           5.50                         7960.90
#
# [8 rows x 78 columns]

# %% [markdown]
# - Unlike *train_data*, the period goes form -131 to 48.

# %%
train_data.nunique()
# Out:
# Period             42
# Biz_Desc            1
# Business_Unit       4
# Segment            24
# Subsegment        134
# Orders           3943
# Revenue          3958
# dtype: int64

# %%
df_market.nunique()
# Out:
# Period                                     180
# China_Core_Inflation_Rate                   28
# China_Exports                              176
# China_GDP                                   15
# China_GDP_from_Construction                 60
#                                           ...
# United_States_Industrial_Production         88
# United_States_Industrial_Production_Mom     34
# United_States_Inflation_Rate                62
# United_States_Interest_Rate                 17
# United_States_Steel_Production             142
# Length: 78, dtype: int64

# %% [markdown]
# ### 3.3. Checking Duplicates

# %%
#checking number of duplicates
train_data.duplicated().sum()
# Out:
# np.int64(0)

# %%
#checking number of duplicates
df_market.duplicated().sum()
# Out:
# np.int64(0)

# %% [markdown]
# - None of the datasets present duplicates.

# %% [markdown]
# ### 3.4. Checking Missing Values

# %%
#checking number of missing values
train_data.isna().sum()
# Out:
# Period           0
# Biz_Desc         0
# Business_Unit    0
# Segment          0
# Subsegment       0
# Orders           0
# Revenue          0
# dtype: int64

# %% [markdown]
# - The train dataset does not present any missing values which is a good sign.

# %%
#checking number of missing values
df_market.isna().sum()
# Out:
# Period                                       0
# China_Core_Inflation_Rate                    2
# China_Exports                                2
# China_GDP                                  165
# China_GDP_from_Construction                120
#                                           ...
# United_States_Industrial_Production          2
# United_States_Industrial_Production_Mom      2
# United_States_Inflation_Rate                 2
# United_States_Interest_Rate                  5
# United_States_Steel_Production               0
# Length: 78, dtype: int64

# %%
pd.set_option('display.max_rows', None)
df_market.isna().sum()/len(df_market) * 100
# Out:
# Period                                       0.000000
# China_Core_Inflation_Rate                    1.111111
# China_Exports                                1.111111
# China_GDP                                   91.666667
# China_GDP_from_Construction                 66.666667
# China_GDP_from_Manufacturing                66.666667
# China_Industrial_Production                  2.222222
# China_Industrial_Production_Mom              5.555556
# China_Inflation_Rate                         1.111111
# China_Interest_Rate                         23.888889
# China_Steel_Production                       0.000000
# France_Core_Inflation_Rate                   1.111111
# France_Exports                               1.111111
# France_GDP                                  91.666667
# France_GDP_from_Construction                66.666667
# France_GDP_from_Manufacturing               66.666667
# France_Industrial_Production                 1.111111
# France_Industrial_Production_Mom             1.111111
# France_Inflation_Rate                        1.111111
# France_Interest_Rate                         2.222222
# France_Steel_Production                     28.333333
# Germany_Core_Inflation_Rate                  1.111111
# Germany_Exports                              1.111111
# Germany_GDP                                 91.666667
# Germany_GDP_from_Construction               66.666667
# Germany_GDP_from_Manufacturing              66.666667
# Germany_Industrial_Production                1.111111
# Germany_Industrial_Production_Mom            1.111111
# Germany_Inflation_Rate                       1.111111
# Germany_Interest_Rate                        2.222222
# Germany_Steel_Production                     0.000000
# Italy_Core_Inflation_Rate                    1.111111
# Italy_Exports                                1.111111
# Italy_GDP                                   91.666667
# Italy_GDP_from_Construction                 66.666667
# Italy_GDP_from_Manufacturing                66.666667
# Italy_Industrial_Production                  1.111111
# Italy_Industrial_Production_Mom              1.111111
# Italy_Inflation_Rate                         1.111111
# Italy_Interest_Rate                          2.222222
# Italy_Steel_Production                      28.333333
# Japan_Core_Inflation_Rate                    1.111111
# Japan_Exports                                1.111111
# Japan_GDP                                   91.666667
# Japan_GDP_from_Construction                 91.666667
# Japan_GDP_from_Manufacturing                91.666667
# Japan_Industrial_Production                  1.111111
# Japan_Industrial_Production_Mom              1.111111
# Japan_Inflation_Rate                         1.111111
# Japan_Interest_Rate                          2.222222
# Japan_Steel_Production                       0.000000
# Switzerland_Core_Inflation_Rate              1.111111
# Switzerland_Exports                          1.111111
# Switzerland_GDP                             91.666667
# Switzerland_Industrial_Production           66.666667
# Switzerland_Industrial_Production_Mom       66.666667
# Switzerland_Inflation_Rate                   1.111111
# Switzerland_Interest_Rate                    2.222222
# United_Kingdom_Core_Inflation_Rate           1.111111
# United_Kingdom_Exports                       1.111111
# United_Kingdom_GDP                          91.666667
# United_Kingdom_GDP_from_Construction        66.666667
# United_Kingdom_GDP_from_Manufacturing       66.666667
# United_Kingdom_Industrial_Production         1.111111
# United_Kingdom_Industrial_Production_Mom     1.111111
# United_Kingdom_Inflation_Rate                1.111111
# United_Kingdom_Interest_Rate                 2.222222
# United_Kingdom_Steel_Production             28.333333
# United_States_Core_Inflation_Rate            1.111111
# United_States_Exports                        1.111111
# United_States_GDP                           91.666667
# United_States_GDP_from_Construction         66.666667
# United_States_GDP_from_Manufacturing        66.666667
# United_States_Industrial_Production          1.111111
# United_States_Industrial_Production_Mom      1.111111
# United_States_Inflation_Rate                 1.111111
# United_States_Interest_Rate                  2.777778
# United_States_Steel_Production               0.000000
# dtype: float64

# %% [markdown]
# - The variables whose missing values represent more than 50% of the data correspond to columns that have informatio about the GDP
# Some columns present a high amount of missing values- almost 92% of the total data. In those cases, the information given is not sufficiently significant to consider these variables.
# -

# %% [markdown]
# - Data that have more than 50% of missing observations correspond to the GDP columns of each country (for example, China_GDP, China_GDP_from_Construction, China_GDP_from_Manufacturing, etc). In these cases, it is normal for the GDP to have a high quantity of missing values considering that the GDP of each country can only be calculated at the end of each year and since we have our data per month, this is the usual behavior.
# - The rest of the columns have less than 50% of missing values (usually the values do not exceed 5%, except for steel production).For the columns corresponding to steel production, there are some countries that for the possitive months (the ones we are going to consider later on merge) have 100% of missing values.

# %%
#creating a variable that has df_market data from the 1 to 42 months 
df_market_months = df_market[df_market['Period'].between(1, 42)]

# %%
pd.set_option('display.max_rows', None)
df_market_months.isna().sum()/len(df_market_months) * 100
# Out:
# Period                                        0.000000
# China_Core_Inflation_Rate                     0.000000
# China_Exports                                 0.000000
# China_GDP                                    92.857143
# China_GDP_from_Construction                  66.666667
# China_GDP_from_Manufacturing                 66.666667
# China_Industrial_Production                   2.380952
# China_Industrial_Production_Mom               0.000000
# China_Inflation_Rate                          0.000000
# China_Interest_Rate                           0.000000
# China_Steel_Production                        0.000000
# France_Core_Inflation_Rate                    0.000000
# France_Exports                                0.000000
# France_GDP                                   92.857143
# France_GDP_from_Construction                 66.666667
# France_GDP_from_Manufacturing                66.666667
# France_Industrial_Production                  0.000000
# France_Industrial_Production_Mom              0.000000
# France_Inflation_Rate                         0.000000
# France_Interest_Rate                          0.000000
# France_Steel_Production                     100.000000
# Germany_Core_Inflation_Rate                   0.000000
# Germany_Exports                               0.000000
# Germany_GDP                                  92.857143
# Germany_GDP_from_Construction                66.666667
# Germany_GDP_from_Manufacturing               66.666667
# Germany_Industrial_Production                 0.000000
# Germany_Industrial_Production_Mom             0.000000
# Germany_Inflation_Rate                        0.000000
# Germany_Interest_Rate                         0.000000
# Germany_Steel_Production                      0.000000
# Italy_Core_Inflation_Rate                     0.000000
# Italy_Exports                                 0.000000
# Italy_GDP                                    92.857143
# Italy_GDP_from_Construction                  66.666667
# Italy_GDP_from_Manufacturing                 66.666667
# Italy_Industrial_Production                   0.000000
# Italy_Industrial_Production_Mom               0.000000
# Italy_Inflation_Rate                          0.000000
# Italy_Interest_Rate                           0.000000
# Italy_Steel_Production                      100.000000
# Japan_Core_Inflation_Rate                     0.000000
# Japan_Exports                                 0.000000
# Japan_GDP                                    92.857143
# Japan_GDP_from_Construction                  92.857143
# Japan_GDP_from_Manufacturing                 92.857143
# Japan_Industrial_Production                   0.000000
# Japan_Industrial_Production_Mom               0.000000
# Japan_Inflation_Rate                          0.000000
# Japan_Interest_Rate                           0.000000
# Japan_Steel_Production                        0.000000
# Switzerland_Core_Inflation_Rate               0.000000
# Switzerland_Exports                           0.000000
# Switzerland_GDP                              92.857143
# Switzerland_Industrial_Production            66.666667
# Switzerland_Industrial_Production_Mom        66.666667
# Switzerland_Inflation_Rate                    0.000000
# Switzerland_Interest_Rate                     0.000000
# United_Kingdom_Core_Inflation_Rate            0.000000
# United_Kingdom_Exports                        0.000000
# United_Kingdom_GDP                           92.857143
# United_Kingdom_GDP_from_Construction         66.666667
# United_Kingdom_GDP_from_Manufacturing        66.666667
# United_Kingdom_Industrial_Production          0.000000
# United_Kingdom_Industrial_Production_Mom      0.000000
# United_Kingdom_Inflation_Rate                 0.000000
# United_Kingdom_Interest_Rate                  0.000000
# United_Kingdom_Steel_Production             100.000000
# United_States_Core_Inflation_Rate             0.000000
# United_States_Exports                         0.000000
# United_States_GDP                            92.857143
# United_States_GDP_from_Construction          66.666667
# United_States_GDP_from_Manufacturing         66.666667
# United_States_Industrial_Production           0.000000
# United_States_Industrial_Production_Mom       0.000000
# United_States_Inflation_Rate                  0.000000
# United_States_Interest_Rate                   2.380952
# United_States_Steel_Production                0.000000
# dtype: float64

# %% [markdown]
# - If we consider only the observations whose period we are going to consider when merging with *train_data*, some of these observations have 100% missing values. In those cases, it is useless to consider them.
# - All variables that have missing values, also have a high percentage (>60%), except for *United_States_Interest_Rate* that has only 2.3% and *China_Industrial_Production* that has 2.3%. Therefore, these are the only variables worth of handling missing values.

# %% [markdown]
# ### 3.5. Checking Outliers

# %%
#setting metric fearures for train_data
metric_features_train= ['Revenue', 'Orders']

# %%
#setting metric fearures for df_market
metric_features_market= ['China_Core_Inflation_Rate', 'China_Exports', 'China_GDP', 
                         'China_Industrial_Production', 'China_Industrial_Production_Mom', 
                         'China_Inflation_Rate', 'China_Interest_Rate', 'China_Steel_Production', 
                         'France_Core_Inflation_Rate', 'France_Exports', 'France_Industrial_Production',
                         'France_Industrial_Production_Mom', 'France_Inflation_Rate', 'France_Interest_Rate', 
                         'Germany_Core_Inflation_Rate', 'Germany_Exports', 'Germany_Industrial_Production', 
                         'Germany_Industrial_Production_Mom', 'Germany_Inflation_Rate', 'Germany_Interest_Rate', 
                         'Germany_Steel_Production', 'Italy_Core_Inflation_Rate', 'Italy_Exports', 'Italy_Industrial_Production',
                         'Italy_Industrial_Production_Mom', 'Italy_Inflation_Rate', 'Italy_Interest_Rate', 'Japan_Core_Inflation_Rate',
                         'Japan_Exports', 'Japan_Industrial_Production', 'Japan_Industrial_Production_Mom', 'Japan_Inflation_Rate', 
                         'Japan_Interest_Rate', 'Japan_Steel_Production', 'Switzerland_Core_Inflation_Rate', 'Switzerland_Exports', 
                         'Switzerland_Inflation_Rate', 'Switzerland_Interest_Rate', 'United_Kingdom_Core_Inflation_Rate', 'United_Kingdom_Exports', 
                         'United_Kingdom_Industrial_Production', 'United_Kingdom_Industrial_Production_Mom', 'United_Kingdom_Inflation_Rate', 
                         'United_Kingdom_Interest_Rate', 'United_States_Core_Inflation_Rate', 'United_States_Exports', 
                         'United_States_Industrial_Production', 'United_States_Industrial_Production_Mom', 'United_States_Inflation_Rate', 
                         'United_States_Steel_Production'
]

# %%
def plot_multiple_boxplots(data, feats, n_cols=2, title="Numeric Variables - Box Plots"):

    #defining grid size
    n_rows = ceil(len(feats) / n_cols)

    fig, axes = plt.subplots(
        n_rows,
        n_cols,
        figsize=(6 * n_cols, 4.5 * n_rows)
    )

    axes = axes.flatten()
    #looping through features
    for i, feat in enumerate(feats):

        #keeping ALL values except missing ones
        values = data[feat].dropna()

        #plotting only if there is data
        if len(values) > 0:
            sns.boxplot(x=values, ax=axes[i], color="#798a40")
            axes[i].set_title(feat, fontsize=10)
        else:
            axes[i].set_title(f"{feat} (no data)", fontsize=10)

    # removing empty subplots
    for j in range(len(feats), len(axes)):
        fig.delaxes(axes[j])

    # final layout adjustments
    plt.suptitle(title, fontsize=18)
    plt.tight_layout(rect=[0, 0, 1, 0.97])
    plt.show()

# %%
#applying the function to our numerical features
plot_multiple_boxplots(train_data, metric_features_train)

# %%
def plot_multiple_boxplots(data, feats, n_cols=3, title="Numeric Variables - Box Plots"):

    #defining grid size
    n_rows = ceil(len(feats) / n_cols)

    fig, axes = plt.subplots(
        n_rows,
        n_cols,
        figsize=(6 * n_cols, 4.5 * n_rows)
    )

    axes = axes.flatten()
    #looping through features
    for i, feat in enumerate(feats):

        #keeping ALL values except missing ones
        values = data[feat].dropna()

        #plotting only if there is data
        if len(values) > 0:
            sns.boxplot(x=values, ax=axes[i], color="#798a40")
            axes[i].set_title(feat, fontsize=10)
        else:
            axes[i].set_title(f"{feat} (no data)", fontsize=10)

    # removing empty subplots
    for j in range(len(feats), len(axes)):
        fig.delaxes(axes[j])

    # final layout adjustments
    plt.suptitle(title, fontsize=18)
    plt.tight_layout(rect=[0, 0, 1, 0.97])
    plt.show()

# %%
#applying the function to our numerical features
plot_multiple_boxplots(df_market, metric_features_market)

# %% [markdown]
# - Even tough there are some outliers, these values correspond to real macroeconomic indicators (like inflation, post-COVID period, etc.). If we applied some capping or transformation to try handle them, we would be distorting the actual economic reality that your model needs to learn from. Therefore, we have decided to keep the data as it is for now.

# %% [markdown]
# ### 3.6. Checking Distribution

# %%
df= pd.DataFrame(train_data[metric_features_train])

# %%
#setting visual style
sns.set_style("white")  # clean background for reports
#sampling the dataset
N = 200_000
sample = train_data.sample(n=min(N, len(train_data)), random_state=42)

#selecting numeric variables
cols = metric_features_train

#defining plotting structure
plots_per_fig = 6   
n_figs = ceil(len(cols) / plots_per_fig)

#looping through figures
for f in range(n_figs):
    
    #selecting subset of columns for current figure
    start = f * plots_per_fig
    end = start + plots_per_fig
    subset_cols = cols[start:end]
    
    #creating subplot grid
    fig, axes = plt.subplots(2, 3, figsize=(14, 8))
    axes = axes.ravel()
    
    #ploting histograms
    for ax, col in zip(axes, subset_cols):
        
        #removing missing values only 
        data = sample[col].dropna()
        
        sns.histplot(
            data,
            bins=60,
            kde=False,
            ax=ax,
            color="#798a40"   
        )
        
        ax.set_title(col, fontsize=10)

    #removing empty subplots
    for j in range(len(subset_cols), len(axes)):
        fig.delaxes(axes[j])
    
        #adjusting layout and display
    plt.tight_layout()
    plt.show()

# %%
#setting visual style
sns.set_style("white")  # clean background for reports
#sampling the dataset
N = 200_000
sample = df_market.sample(n=min(N, len(df_market)), random_state=42)

#selecting numeric variables
cols = metric_features_market

#defining plotting structure
plots_per_fig = 6   
n_figs = ceil(len(cols) / plots_per_fig)

#looping through figures
for f in range(n_figs):
    
    #selecting subset of columns for current figure
    start = f * plots_per_fig
    end = start + plots_per_fig
    subset_cols = cols[start:end]
    
    #creating subplot grid
    fig, axes = plt.subplots(2, 3, figsize=(14, 8))
    axes = axes.ravel()
    
    #ploting histograms
    for ax, col in zip(axes, subset_cols):
        
        #removing missing values only 
        data = sample[col].dropna()
        
        sns.histplot(
            data,
            bins=60,
            kde=False,
            ax=ax,
            color="#798a40"   
        )
        
        ax.set_title(col, fontsize=10)

    #removing empty subplots
    for j in range(len(subset_cols), len(axes)):
        fig.delaxes(axes[j])
    
        #adjusting layout and display
    plt.tight_layout()
    plt.show()

# %% [markdown]
# ### 3.7. Checking Correlation between variables

# %%
#checking correlation between variables 
#we are going to use spearman correlation since our variables do not follow a normal distribution
cor_spearman = df_market[metric_features_market].corr(method ='spearman')
cor_spearman
# Out:
#                                           China_Core_Inflation_Rate  \
# China_Core_Inflation_Rate                                  1.000000
# China_Exports                                             -0.601535
# China_GDP                                                 -0.641005
# China_Industrial_Production                                0.350778
# China_Industrial_Production_Mom                            0.110067
# China_Inflation_Rate                                       0.489509
# China_Interest_Rate                                        0.763456
# China_Steel_Production                                    -0.519185
# France_Core_Inflation_Rate                                -0.470539
# France_Exports                                            -0.445736
# France_Industrial_Production                               0.285797
# France_Industrial_Production_Mom                          -0.004831
# France_Inflation_Rate                                     -0.197923
# France_Interest_Rate                                      -0.279979
# Germany_Core_Inflation_Rate                               -0.407548
# Germany_Exports                                           -0.504072
# Germany_Industrial_Production                              0.525343
# Germany_Industrial_Production_Mom                          0.014680
# Germany_Inflation_Rate                                    -0.268949
# Germany_Interest_Rate                                     -0.279979
# Germany_Steel_Production                                   0.634149
# Italy_Core_Inflation_Rate                                 -0.274558
# Italy_Exports                                             -0.499941
# Italy_Industrial_Production                                0.328264
# Italy_Industrial_Production_Mom                            0.025947
# Italy_Inflation_Rate                                      -0.064153
# Italy_Interest_Rate                                       -0.279979
# Japan_Core_Inflation_Rate                                 -0.209961
# Japan_Exports                                             -0.436509
# Japan_Industrial_Production                                0.208302
# Japan_Industrial_Production_Mom                            0.046828
# Japan_Inflation_Rate                                      -0.263937
# Japan_Interest_Rate                                        0.019516
# Japan_Steel_Production                                     0.670010
# Switzerland_Core_Inflation_Rate                           -0.285352
# Switzerland_Exports                                       -0.554471
# Switzerland_Inflation_Rate                                -0.156341
# Switzerland_Interest_Rate                                 -0.298879
# United_Kingdom_Core_Inflation_Rate                        -0.224527
# United_Kingdom_Exports                                    -0.484753
# United_Kingdom_Industrial_Production                       0.129136
# United_Kingdom_Industrial_Production_Mom                   0.063294
# United_Kingdom_Inflation_Rate                             -0.045124
# United_Kingdom_Interest_Rate                              -0.278393
# United_States_Core_Inflation_Rate                         -0.419716
# United_States_Exports                                     -0.410172
# United_States_Industrial_Production                        0.244042
# United_States_Industrial_Production_Mom                    0.004236
# United_States_Inflation_Rate                              -0.203296
# United_States_Steel_Production                             0.346979
#
#                                           China_Exports  China_GDP  \
# China_Core_Inflation_Rate                     -0.601535  -0.641005
# China_Exports                                  1.000000   0.932143
# China_GDP                                      0.932143   1.000000
# China_Industrial_Production                   -0.534005  -0.705988
# China_Industrial_Production_Mom               -0.253287  -0.536429
# China_Inflation_Rate                          -0.556201  -0.694721
# China_Interest_Rate                           -0.716840  -0.943685
# China_Steel_Production                         0.765034   0.807143
# France_Core_Inflation_Rate                     0.413557   0.481217
# France_Exports                                 0.755412   0.942857
# France_Industrial_Production                  -0.136397  -0.196429
# France_Industrial_Production_Mom               0.005371  -0.062556
# France_Inflation_Rate                          0.319072   0.291332
# France_Interest_Rate                           0.028865   0.035108
# Germany_Core_Inflation_Rate                    0.654029   0.622318
# Germany_Exports                                0.807176   0.967857
# Germany_Industrial_Production                 -0.493803  -0.685714
# Germany_Industrial_Production_Mom             -0.028803  -0.319286
# Germany_Inflation_Rate                         0.450424   0.448435
# Germany_Interest_Rate                          0.028865   0.035108
# Germany_Steel_Production                      -0.647104  -0.427167
# Italy_Core_Inflation_Rate                      0.159496   0.195518
# Italy_Exports                                  0.709960   0.979446
# Italy_Industrial_Production                   -0.155663  -0.210903
# Italy_Industrial_Production_Mom               -0.019941  -0.129149
# Italy_Inflation_Rate                           0.133078   0.021429
# Italy_Interest_Rate                            0.028865   0.035108
# Japan_Core_Inflation_Rate                      0.510863   0.516995
# Japan_Exports                                  0.709784   0.878571
# Japan_Industrial_Production                   -0.136730  -0.346429
# Japan_Industrial_Production_Mom               -0.049301  -0.431128
# Japan_Inflation_Rate                           0.516477   0.579607
# Japan_Interest_Rate                           -0.288858  -0.464835
# Japan_Steel_Production                        -0.671404  -0.809652
# Switzerland_Core_Inflation_Rate                0.652069   0.744187
# Switzerland_Exports                            0.826590   0.942857
# Switzerland_Inflation_Rate                     0.541875   0.582143
# Switzerland_Interest_Rate                      0.099458   0.075593
# United_Kingdom_Core_Inflation_Rate             0.340300   0.372762
# United_Kingdom_Exports                         0.780474   0.975000
# United_Kingdom_Industrial_Production          -0.067462  -0.058981
# United_Kingdom_Industrial_Production_Mom      -0.037299  -0.201966
# United_Kingdom_Inflation_Rate                  0.165909   0.175000
# United_Kingdom_Interest_Rate                   0.332794   0.403616
# United_States_Core_Inflation_Rate              0.594231   0.703146
# United_States_Exports                          0.779905   0.910714
# United_States_Industrial_Production           -0.144228  -0.480787
# United_States_Industrial_Production_Mom       -0.012998  -0.304388
# United_States_Inflation_Rate                   0.491679   0.550985
# United_States_Steel_Production                -0.088536  -0.175000
#
#                                           China_Industrial_Production  \
# China_Core_Inflation_Rate                                    0.350778
# China_Exports                                               -0.534005
# China_GDP                                                   -0.705988
# China_Industrial_Production                                  1.000000
# China_Industrial_Production_Mom                              0.483968
# China_Inflation_Rate                                         0.298135
# China_Interest_Rate                                          0.475174
# China_Steel_Production                                      -0.574685
# France_Core_Inflation_Rate                                  -0.303811
# France_Exports                                              -0.630758
# France_Industrial_Production                                 0.148160
# France_Industrial_Production_Mom                            -0.043170
# France_Inflation_Rate                                       -0.161158
# France_Interest_Rate                                         0.167330
# Germany_Core_Inflation_Rate                                 -0.438914
# Germany_Exports                                             -0.668892
# Germany_Industrial_Production                                0.487819
# Germany_Industrial_Production_Mom                            0.012445
# Germany_Inflation_Rate                                      -0.230853
# Germany_Interest_Rate                                        0.167330
# Germany_Steel_Production                                     0.509135
# Italy_Core_Inflation_Rate                                   -0.004785
# Italy_Exports                                               -0.532711
# Italy_Industrial_Production                                  0.080351
# Italy_Industrial_Production_Mom                             -0.020315
# Italy_Inflation_Rate                                         0.020170
# Italy_Interest_Rate                                          0.167330
# Japan_Core_Inflation_Rate                                   -0.440180
# Japan_Exports                                               -0.492360
# Japan_Industrial_Production                                  0.249441
# Japan_Industrial_Production_Mom                              0.100370
# Japan_Inflation_Rate                                        -0.443892
# Japan_Interest_Rate                                          0.452108
# Japan_Steel_Production                                       0.602086
# Switzerland_Core_Inflation_Rate                             -0.473460
# Switzerland_Exports                                         -0.612069
# Switzerland_Inflation_Rate                                  -0.347242
# Switzerland_Interest_Rate                                    0.175005
# United_Kingdom_Core_Inflation_Rate                          -0.118474
# United_Kingdom_Exports                                      -0.697337
# United_Kingdom_Industrial_Production                         0.088079
# United_Kingdom_Industrial_Production_Mom                    -0.068754
# United_Kingdom_Inflation_Rate                                0.003491
# United_Kingdom_Interest_Rate                                -0.349172
# United_States_Core_Inflation_Rate                           -0.597015
# United_States_Exports                                       -0.527057
# United_States_Industrial_Production                          0.388441
# United_States_Industrial_Production_Mom                      0.171938
# United_States_Inflation_Rate                                -0.232295
# United_States_Steel_Production                               0.212601
#
#                                           China_Industrial_Production_Mom  \
# China_Core_Inflation_Rate                                        0.110067
# China_Exports                                                   -0.253287
# China_GDP                                                       -0.536429
# China_Industrial_Production                                      0.483968
# China_Industrial_Production_Mom                                  1.000000
# China_Inflation_Rate                                             0.304943
# China_Interest_Rate                                              0.031023
# China_Steel_Production                                          -0.199254
# France_Core_Inflation_Rate                                      -0.143508
# France_Exports                                                  -0.453833
# France_Industrial_Production                                    -0.143587
# France_Industrial_Production_Mom                                -0.031336
# France_Inflation_Rate                                           -0.124772
# France_Interest_Rate                                             0.163493
# Germany_Core_Inflation_Rate                                     -0.345765
# Germany_Exports                                                 -0.441432
# Germany_Industrial_Production                                    0.027158
# Germany_Industrial_Production_Mom                                0.067522
# Germany_Inflation_Rate                                          -0.167676
# Germany_Interest_Rate                                            0.163493
# Germany_Steel_Production                                         0.110436
# Italy_Core_Inflation_Rate                                        0.084317
# Italy_Exports                                                   -0.300866
# Italy_Industrial_Production                                     -0.255720
# Italy_Industrial_Production_Mom                                 -0.109994
# Italy_Inflation_Rate                                            -0.034989
# Italy_Interest_Rate                                              0.163493
# Japan_Core_Inflation_Rate                                       -0.262201
# Japan_Exports                                                   -0.369701
# Japan_Industrial_Production                                     -0.158425
# Japan_Industrial_Production_Mom                                  0.107244
# Japan_Inflation_Rate                                            -0.257242
# Japan_Interest_Rate                                              0.273153
# Japan_Steel_Production                                           0.137530
# Switzerland_Core_Inflation_Rate                                 -0.333531
# Switzerland_Exports                                             -0.337783
# Switzerland_Inflation_Rate                                      -0.310514
# Switzerland_Interest_Rate                                        0.197482
# United_Kingdom_Core_Inflation_Rate                              -0.059747
# United_Kingdom_Exports                                          -0.350008
# United_Kingdom_Industrial_Production                            -0.057605
# United_Kingdom_Industrial_Production_Mom                        -0.015859
# United_Kingdom_Inflation_Rate                                   -0.015704
# United_Kingdom_Interest_Rate                                    -0.163640
# United_States_Core_Inflation_Rate                               -0.408471
# United_States_Exports                                           -0.410135
# United_States_Industrial_Production                             -0.062856
# United_States_Industrial_Production_Mom                          0.074491
# United_States_Inflation_Rate                                    -0.183883
# United_States_Steel_Production                                  -0.031805
#
#                                           China_Inflation_Rate  \
# China_Core_Inflation_Rate                             0.489509
# China_Exports                                        -0.556201
# China_GDP                                            -0.694721
# China_Industrial_Production                           0.298135
# China_Industrial_Production_Mom                       0.304943
# China_Inflation_Rate                                  1.000000
# China_Interest_Rate                                   0.473119
# China_Steel_Production                               -0.457820
# France_Core_Inflation_Rate                           -0.131786
# France_Exports                                       -0.592795
# France_Industrial_Production                          0.044202
# France_Industrial_Production_Mom                     -0.008531
# France_Inflation_Rate                                 0.015568
# France_Interest_Rate                                 -0.077517
# Germany_Core_Inflation_Rate                          -0.519143
# Germany_Exports                                      -0.596268
# Germany_Industrial_Production                         0.307423
# Germany_Industrial_Production_Mom                     0.031334
# Germany_Inflation_Rate                               -0.146061
# Germany_Interest_Rate                                -0.077517
# Germany_Steel_Production                              0.301483
# Italy_Core_Inflation_Rate                            -0.000348
# Italy_Exports                                        -0.533353
# Italy_Industrial_Production                           0.043632
# Italy_Industrial_Production_Mom                      -0.051693
# Italy_Inflation_Rate                                  0.076852
# Italy_Interest_Rate                                  -0.077517
# Japan_Core_Inflation_Rate                            -0.316169
# Japan_Exports                                        -0.583232
# Japan_Industrial_Production                           0.053194
# Japan_Industrial_Production_Mom                       0.064640
# Japan_Inflation_Rate                                 -0.312842
# Japan_Interest_Rate                                   0.124660
# Japan_Steel_Production                                0.462947
# Switzerland_Core_Inflation_Rate                      -0.348244
# Switzerland_Exports                                  -0.549536
# Switzerland_Inflation_Rate                           -0.239571
# Switzerland_Interest_Rate                            -0.065212
# United_Kingdom_Core_Inflation_Rate                   -0.102627
# United_Kingdom_Exports                               -0.490632
# United_Kingdom_Industrial_Production                 -0.106269
# United_Kingdom_Industrial_Production_Mom              0.034190
# United_Kingdom_Inflation_Rate                         0.105715
# United_Kingdom_Interest_Rate                         -0.117586
# United_States_Core_Inflation_Rate                    -0.334955
# United_States_Exports                                -0.541774
# United_States_Industrial_Production                   0.289531
# United_States_Industrial_Production_Mom               0.082164
# United_States_Inflation_Rate                         -0.142046
# United_States_Steel_Production                        0.358545
#
#                                           China_Interest_Rate  \
# China_Core_Inflation_Rate                            0.763456
# China_Exports                                       -0.716840
# China_GDP                                           -0.943685
# China_Industrial_Production                          0.475174
# China_Industrial_Production_Mom                      0.031023
# China_Inflation_Rate                                 0.473119
# China_Interest_Rate                                  1.000000
# China_Steel_Production                              -0.594454
# France_Core_Inflation_Rate                          -0.732886
# France_Exports                                      -0.712972
# France_Industrial_Production                         0.077431
# France_Industrial_Production_Mom                    -0.013528
# France_Inflation_Rate                               -0.583372
# France_Interest_Rate                                -0.328250
# Germany_Core_Inflation_Rate                         -0.546895
# Germany_Exports                                     -0.784519
# Germany_Industrial_Production                        0.486564
# Germany_Industrial_Production_Mom                    0.040796
# Germany_Inflation_Rate                              -0.611105
# Germany_Interest_Rate                               -0.328250
# Germany_Steel_Production                             0.711570
# Italy_Core_Inflation_Rate                           -0.571639
# Italy_Exports                                       -0.712482
# Italy_Industrial_Production                          0.321599
# Italy_Industrial_Production_Mom                      0.043731
# Italy_Inflation_Rate                                -0.473344
# Italy_Interest_Rate                                 -0.328250
# Japan_Core_Inflation_Rate                           -0.181861
# Japan_Exports                                       -0.619142
# Japan_Industrial_Production                          0.258809
# Japan_Industrial_Production_Mom                     -0.018581
# Japan_Inflation_Rate                                -0.212922
# Japan_Interest_Rate                                  0.159165
# Japan_Steel_Production                               0.867592
# Switzerland_Core_Inflation_Rate                     -0.581902
# Switzerland_Exports                                 -0.811667
# Switzerland_Inflation_Rate                          -0.520657
# Switzerland_Interest_Rate                           -0.435865
# United_Kingdom_Core_Inflation_Rate                  -0.607052
# United_Kingdom_Exports                              -0.792662
# United_Kingdom_Industrial_Production                 0.504204
# United_Kingdom_Industrial_Production_Mom             0.089586
# United_Kingdom_Inflation_Rate                       -0.518614
# United_Kingdom_Interest_Rate                        -0.386924
# United_States_Core_Inflation_Rate                   -0.649751
# United_States_Exports                               -0.619018
# United_States_Industrial_Production                  0.170641
# United_States_Industrial_Production_Mom             -0.071090
# United_States_Inflation_Rate                        -0.632366
# United_States_Steel_Production                       0.397936
#
#                                           China_Steel_Production  \
# China_Core_Inflation_Rate                              -0.519185
# China_Exports                                           0.765034
# China_GDP                                               0.807143
# China_Industrial_Production                            -0.574685
# China_Industrial_Production_Mom                        -0.199254
# China_Inflation_Rate                                   -0.457820
# China_Interest_Rate                                    -0.594454
# China_Steel_Production                                  1.000000
# France_Core_Inflation_Rate                              0.242274
# France_Exports                                          0.664963
# France_Industrial_Production                           -0.144723
# France_Industrial_Production_Mom                        0.036326
# France_Inflation_Rate                                   0.151437
# France_Interest_Rate                                   -0.263927
# Germany_Core_Inflation_Rate                             0.452771
# Germany_Exports                                         0.761123
# Germany_Industrial_Production                          -0.481255
# Germany_Industrial_Production_Mom                      -0.014447
# Germany_Inflation_Rate                                  0.275773
# Germany_Interest_Rate                                  -0.263927
# Germany_Steel_Production                               -0.517550
# Italy_Core_Inflation_Rate                              -0.084189
# Italy_Exports                                           0.681100
# Italy_Industrial_Production                            -0.110009
# Italy_Industrial_Production_Mom                        -0.014730
# Italy_Inflation_Rate                                   -0.043872
# Italy_Interest_Rate                                    -0.263927
# Japan_Core_Inflation_Rate                               0.363800
# Japan_Exports                                           0.585933
# Japan_Industrial_Production                            -0.177145
# Japan_Industrial_Production_Mom                        -0.018828
# Japan_Inflation_Rate                                    0.358737
# Japan_Interest_Rate                                    -0.535913
# Japan_Steel_Production                                 -0.682681
# Switzerland_Core_Inflation_Rate                         0.565140
# Switzerland_Exports                                     0.789712
# Switzerland_Inflation_Rate                              0.426544
# Switzerland_Interest_Rate                              -0.168732
# United_Kingdom_Core_Inflation_Rate                      0.114029
# United_Kingdom_Exports                                  0.789087
# United_Kingdom_Industrial_Production                    0.081263
# United_Kingdom_Industrial_Production_Mom                0.012418
# United_Kingdom_Inflation_Rate                          -0.018187
# United_Kingdom_Interest_Rate                            0.186418
# United_States_Core_Inflation_Rate                       0.454955
# United_States_Exports                                   0.655751
# United_States_Industrial_Production                    -0.306479
# United_States_Industrial_Production_Mom                 0.051236
# United_States_Inflation_Rate                            0.344398
# United_States_Steel_Production                         -0.123561
#
#                                           France_Core_Inflation_Rate  \
# China_Core_Inflation_Rate                                  -0.470539
# China_Exports                                               0.413557
# China_GDP                                                   0.481217
# China_Industrial_Production                                -0.303811
# China_Industrial_Production_Mom                            -0.143508
# China_Inflation_Rate                                       -0.131786
# China_Interest_Rate                                        -0.732886
# China_Steel_Production                                      0.242274
# France_Core_Inflation_Rate                                  1.000000
# France_Exports                                              0.558090
# France_Industrial_Production                                0.022037
# France_Industrial_Production_Mom                           -0.034403
# France_Inflation_Rate                                       0.811739
# France_Interest_Rate                                        0.473173
# Germany_Core_Inflation_Rate                                 0.576502
# Germany_Exports                                             0.517005
# Germany_Industrial_Production                              -0.232832
# Germany_Industrial_Production_Mom                          -0.131953
# Germany_Inflation_Rate                                      0.765191
# Germany_Interest_Rate                                       0.473173
# Germany_Steel_Production                                   -0.374566
# Italy_Core_Inflation_Rate                                   0.724477
# Italy_Exports                                               0.509968
# Italy_Industrial_Production                                -0.191114
# Italy_Industrial_Production_Mom                            -0.126138
# Italy_Inflation_Rate                                        0.638136
# Italy_Interest_Rate                                         0.473173
# Japan_Core_Inflation_Rate                                   0.295475
# Japan_Exports                                               0.421924
# Japan_Industrial_Production                                -0.070081
# Japan_Industrial_Production_Mom                            -0.041439
# Japan_Inflation_Rate                                        0.289427
# Japan_Interest_Rate                                        -0.069579
# Japan_Steel_Production                                     -0.479855
# Switzerland_Core_Inflation_Rate                             0.483153
# Switzerland_Exports                                         0.493311
# Switzerland_Inflation_Rate                                  0.530937
# Switzerland_Interest_Rate                                   0.458840
# United_Kingdom_Core_Inflation_Rate                          0.719575
# United_Kingdom_Exports                                      0.509956
# United_Kingdom_Industrial_Production                       -0.434278
# United_Kingdom_Industrial_Production_Mom                   -0.130584
# United_Kingdom_Inflation_Rate                               0.638881
# United_Kingdom_Interest_Rate                                0.565150
# United_States_Core_Inflation_Rate                           0.710207
# United_States_Exports                                       0.464588
# United_States_Industrial_Production                         0.095544
# United_States_Industrial_Production_Mom                    -0.001930
# United_States_Inflation_Rate                                0.687309
# United_States_Steel_Production                             -0.015814
#
#                                           France_Exports  ...  \
# China_Core_Inflation_Rate                      -0.445736  ...
# China_Exports                                   0.755412  ...
# China_GDP                                       0.942857  ...
# China_Industrial_Production                    -0.630758  ...
# China_Industrial_Production_Mom                -0.453833  ...
# China_Inflation_Rate                           -0.592795  ...
# China_Interest_Rate                            -0.712972  ...
# China_Steel_Production                          0.664963  ...
# France_Core_Inflation_Rate                      0.558090  ...
# France_Exports                                  1.000000  ...
# France_Industrial_Production                    0.067335  ...
# France_Industrial_Production_Mom                0.021951  ...
# France_Inflation_Rate                           0.459902  ...
# France_Interest_Rate                            0.057536  ...
# Germany_Core_Inflation_Rate                     0.758511  ...
# Germany_Exports                                 0.952788  ...
# Germany_Industrial_Production                  -0.387404  ...
# Germany_Industrial_Production_Mom              -0.083467  ...
# Germany_Inflation_Rate                          0.568098  ...
# Germany_Interest_Rate                           0.057536  ...
# Germany_Steel_Production                       -0.501423  ...
# Italy_Core_Inflation_Rate                       0.229137  ...
# Italy_Exports                                   0.822448  ...
# Italy_Industrial_Production                    -0.045462  ...
# Italy_Industrial_Production_Mom                -0.026996  ...
# Italy_Inflation_Rate                            0.267583  ...
# Italy_Interest_Rate                             0.057536  ...
# Japan_Core_Inflation_Rate                       0.589450  ...
# Japan_Exports                                   0.822955  ...
# Japan_Industrial_Production                    -0.050521  ...
# Japan_Industrial_Production_Mom                -0.100414  ...
# Japan_Inflation_Rate                            0.565898  ...
# Japan_Interest_Rate                            -0.396158  ...
# Japan_Steel_Production                         -0.656734  ...
# Switzerland_Core_Inflation_Rate                 0.772564  ...
# Switzerland_Exports                             0.871735  ...
# Switzerland_Inflation_Rate                      0.671112  ...
# Switzerland_Interest_Rate                       0.081362  ...
# United_Kingdom_Core_Inflation_Rate              0.435659  ...
# United_Kingdom_Exports                          0.904684  ...
# United_Kingdom_Industrial_Production           -0.053031  ...
# United_Kingdom_Industrial_Production_Mom       -0.020413  ...
# United_Kingdom_Inflation_Rate                   0.274422  ...
# United_Kingdom_Interest_Rate                    0.566934  ...
# United_States_Core_Inflation_Rate               0.774614  ...
# United_States_Exports                           0.892917  ...
# United_States_Industrial_Production            -0.164116  ...
# United_States_Industrial_Production_Mom        -0.113626  ...
# United_States_Inflation_Rate                    0.580744  ...
# United_States_Steel_Production                 -0.117215  ...
#
#                                           United_Kingdom_Industrial_Production  \
# China_Core_Inflation_Rate                                             0.129136
# China_Exports                                                        -0.067462
# China_GDP                                                            -0.058981
# China_Industrial_Production                                           0.088079
# China_Industrial_Production_Mom                                      -0.057605
# China_Inflation_Rate                                                 -0.106269
# China_Interest_Rate                                                   0.504204
# China_Steel_Production                                                0.081263
# France_Core_Inflation_Rate                                           -0.434278
# France_Exports                                                       -0.053031
# France_Industrial_Production                                         -0.039428
# France_Industrial_Production_Mom                                      0.067646
# France_Inflation_Rate                                                -0.570689
# France_Interest_Rate                                                 -0.356312
# Germany_Core_Inflation_Rate                                          -0.157694
# Germany_Exports                                                      -0.034575
# Germany_Industrial_Production                                         0.038747
# Germany_Industrial_Production_Mom                                    -0.005463
# Germany_Inflation_Rate                                               -0.505229
# Germany_Interest_Rate                                                -0.356312
# Germany_Steel_Production                                              0.179715
# Italy_Core_Inflation_Rate                                            -0.583008
# Italy_Exports                                                        -0.082104
# Italy_Industrial_Production                                           0.012007
# Italy_Industrial_Production_Mom                                       0.073188
# Italy_Inflation_Rate                                                 -0.578592
# Italy_Interest_Rate                                                  -0.356312
# Japan_Core_Inflation_Rate                                            -0.011971
# Japan_Exports                                                        -0.043478
# Japan_Industrial_Production                                           0.034867
# Japan_Industrial_Production_Mom                                       0.037208
# Japan_Inflation_Rate                                                 -0.013021
# Japan_Interest_Rate                                                   0.001507
# Japan_Steel_Production                                                0.188380
# Switzerland_Core_Inflation_Rate                                      -0.287590
# Switzerland_Exports                                                  -0.108155
# Switzerland_Inflation_Rate                                           -0.427708
# Switzerland_Interest_Rate                                            -0.409217
# United_Kingdom_Core_Inflation_Rate                                   -0.619093
# United_Kingdom_Exports                                               -0.090431
# United_Kingdom_Industrial_Production                                  1.000000
# United_Kingdom_Industrial_Production_Mom                              0.331221
# United_Kingdom_Inflation_Rate                                        -0.616358
# United_Kingdom_Interest_Rate                                         -0.174276
# United_States_Core_Inflation_Rate                                    -0.269755
# United_States_Exports                                                -0.025344
# United_States_Industrial_Production                                  -0.219396
# United_States_Industrial_Production_Mom                               0.022841
# United_States_Inflation_Rate                                         -0.452426
# United_States_Steel_Production                                        0.062067
#
#                                           United_Kingdom_Industrial_Production_Mom  \
# China_Core_Inflation_Rate                                                 0.063294
# China_Exports                                                            -0.037299
# China_GDP                                                                -0.201966
# China_Industrial_Production                                              -0.068754
# China_Industrial_Production_Mom                                          -0.015859
# China_Inflation_Rate                                                      0.034190
# China_Interest_Rate                                                       0.089586
# China_Steel_Production                                                    0.012418
# France_Core_Inflation_Rate                                               -0.130584
# France_Exports                                                           -0.020413
# France_Industrial_Production                                             -0.026367
# France_Industrial_Production_Mom                                          0.243666
# France_Inflation_Rate                                                    -0.174541
# France_Interest_Rate                                                     -0.073886
# Germany_Core_Inflation_Rate                                              -0.065659
# Germany_Exports                                                          -0.026322
# Germany_Industrial_Production                                            -0.092446
# Germany_Industrial_Production_Mom                                         0.124548
# Germany_Inflation_Rate                                                   -0.186519
# Germany_Interest_Rate                                                    -0.073886
# Germany_Steel_Production                                                 -0.011555
# Italy_Core_Inflation_Rate                                                -0.129073
# Italy_Exports                                                            -0.009804
# Italy_Industrial_Production                                              -0.116261
# Italy_Industrial_Production_Mom                                           0.146558
# Italy_Inflation_Rate                                                     -0.180408
# Italy_Interest_Rate                                                      -0.073886
# Japan_Core_Inflation_Rate                                                 0.044988
# Japan_Exports                                                            -0.104494
# Japan_Industrial_Production                                              -0.157645
# Japan_Industrial_Production_Mom                                           0.053000
# Japan_Inflation_Rate                                                      0.036503
# Japan_Interest_Rate                                                       0.002929
# Japan_Steel_Production                                                   -0.028550
# Switzerland_Core_Inflation_Rate                                          -0.096980
# Switzerland_Exports                                                      -0.053033
# Switzerland_Inflation_Rate                                               -0.173861
# Switzerland_Interest_Rate                                                -0.093320
# United_Kingdom_Core_Inflation_Rate                                       -0.130469
# United_Kingdom_Exports                                                   -0.006462
# United_Kingdom_Industrial_Production                                      0.331221
# United_Kingdom_Industrial_Production_Mom                                  1.000000
# United_Kingdom_Inflation_Rate                                            -0.125374
# United_Kingdom_Interest_Rate                                             -0.020200
# United_States_Core_Inflation_Rate                                        -0.130730
# United_States_Exports                                                    -0.054542
# United_States_Industrial_Production                                      -0.128486
# United_States_Industrial_Production_Mom                                   0.177491
# United_States_Inflation_Rate                                             -0.140052
# United_States_Steel_Production                                           -0.059440
#
#                                           United_Kingdom_Inflation_Rate  \
# China_Core_Inflation_Rate                                     -0.045124
# China_Exports                                                  0.165909
# China_GDP                                                      0.175000
# China_Industrial_Production                                    0.003491
# China_Industrial_Production_Mom                               -0.015704
# China_Inflation_Rate                                           0.105715
# China_Interest_Rate                                           -0.518614
# China_Steel_Production                                        -0.018187
# France_Core_Inflation_Rate                                     0.638881
# France_Exports                                                 0.274422
# France_Industrial_Production                                   0.239327
# France_Industrial_Production_Mom                              -0.025163
# France_Inflation_Rate                                          0.871284
# France_Interest_Rate                                           0.465025
# Germany_Core_Inflation_Rate                                    0.363150
# Germany_Exports                                                0.217699
# Germany_Industrial_Production                                  0.099499
# Germany_Industrial_Production_Mom                             -0.028451
# Germany_Inflation_Rate                                         0.803293
# Germany_Interest_Rate                                          0.465025
# Germany_Steel_Production                                      -0.134126
# Italy_Core_Inflation_Rate                                      0.759518
# Italy_Exports                                                  0.254310
# Italy_Industrial_Production                                    0.016302
# Italy_Industrial_Production_Mom                               -0.048679
# Italy_Inflation_Rate                                           0.894761
# Italy_Interest_Rate                                            0.465025
# Japan_Core_Inflation_Rate                                      0.263809
# Japan_Exports                                                  0.258747
# Japan_Industrial_Production                                    0.155408
# Japan_Industrial_Production_Mom                                0.023120
# Japan_Inflation_Rate                                           0.229224
# Japan_Interest_Rate                                           -0.042293
# Japan_Steel_Production                                        -0.124144
# Switzerland_Core_Inflation_Rate                                0.511544
# Switzerland_Exports                                            0.237221
# Switzerland_Inflation_Rate                                     0.682324
# Switzerland_Interest_Rate                                      0.543993
# United_Kingdom_Core_Inflation_Rate                             0.926861
# United_Kingdom_Exports                                         0.251939
# United_Kingdom_Industrial_Production                          -0.616358
# United_Kingdom_Industrial_Production_Mom                      -0.125374
# United_Kingdom_Inflation_Rate                                  1.000000
# United_Kingdom_Interest_Rate                                   0.353424
# United_States_Core_Inflation_Rate                              0.386939
# United_States_Exports                                          0.293932
# United_States_Industrial_Production                            0.525551
# United_States_Industrial_Production_Mom                        0.132156
# United_States_Inflation_Rate                                   0.742927
# United_States_Steel_Production                                 0.136459
#
#                                           United_Kingdom_Interest_Rate  \
# China_Core_Inflation_Rate                                    -0.278393
# China_Exports                                                 0.332794
# China_GDP                                                     0.403616
# China_Industrial_Production                                  -0.349172
# China_Industrial_Production_Mom                              -0.163640
# China_Inflation_Rate                                         -0.117586
# China_Interest_Rate                                          -0.386924
# China_Steel_Production                                        0.186418
# France_Core_Inflation_Rate                                    0.565150
# France_Exports                                                0.566934
# France_Industrial_Production                                  0.043892
# France_Industrial_Production_Mom                             -0.056706
# France_Inflation_Rate                                         0.501436
# France_Interest_Rate                                          0.576402
# Germany_Core_Inflation_Rate                                   0.533502
# Germany_Exports                                               0.489005
# Germany_Industrial_Production                                -0.355879
# Germany_Industrial_Production_Mom                            -0.148351
# Germany_Inflation_Rate                                        0.464187
# Germany_Interest_Rate                                         0.576402
# Germany_Steel_Production                                     -0.323862
# Italy_Core_Inflation_Rate                                     0.519184
# Italy_Exports                                                 0.440225
# Italy_Industrial_Production                                  -0.304692
# Italy_Industrial_Production_Mom                              -0.121817
# Italy_Inflation_Rate                                          0.292931
# Italy_Interest_Rate                                           0.576402
# Japan_Core_Inflation_Rate                                     0.664242
# Japan_Exports                                                 0.494676
# Japan_Industrial_Production                                  -0.156791
# Japan_Industrial_Production_Mom                              -0.084879
# Japan_Inflation_Rate                                          0.628192
# Japan_Interest_Rate                                           0.165960
# Japan_Steel_Production                                       -0.293521
# Switzerland_Core_Inflation_Rate                               0.582173
# Switzerland_Exports                                           0.430422
# Switzerland_Inflation_Rate                                    0.507648
# Switzerland_Interest_Rate                                     0.579947
# United_Kingdom_Core_Inflation_Rate                            0.500423
# United_Kingdom_Exports                                        0.498797
# United_Kingdom_Industrial_Production                         -0.174276
# United_Kingdom_Industrial_Production_Mom                     -0.020200
# United_Kingdom_Inflation_Rate                                 0.353424
# United_Kingdom_Interest_Rate                                  1.000000
# United_States_Core_Inflation_Rate                             0.509679
# United_States_Exports                                         0.590064
# United_States_Industrial_Production                          -0.049382
# ...
# China_Exports                                                       -0.144228
# China_GDP                                                           -0.480787
# China_Industrial_Production                                          0.388441
# China_Industrial_Production_Mom                                     -0.062856
# China_Inflation_Rate                                                 0.289531
# China_Interest_Rate                                                  0.170641
# China_Steel_Production                                              -0.306479
# France_Core_Inflation_Rate                                           0.095544
# France_Exports                                                      -0.164116
# France_Industrial_Production                                         0.293918
# France_Industrial_Production_Mom                                    -0.046308
# France_Inflation_Rate                                                0.443120
# France_Interest_Rate                                                 0.105230
# Germany_Core_Inflation_Rate                                          0.011517
# Germany_Exports                                                     -0.203257
# Germany_Industrial_Production                                        0.466349
# Germany_Industrial_Production_Mom                                    0.016258
# Germany_Inflation_Rate                                               0.333448
# Germany_Interest_Rate                                                0.105230
# Germany_Steel_Production                                             0.309829
# Italy_Core_Inflation_Rate                                            0.213758
# Italy_Exports                                                       -0.155926
# Italy_Industrial_Production                                          0.295739
# Italy_Industrial_Production_Mom                                      0.018617
# Italy_Inflation_Rate                                                 0.546209
# Italy_Interest_Rate                                                  0.105230
# Japan_Core_Inflation_Rate                                            0.016956
# Japan_Exports                                                       -0.034047
# Japan_Industrial_Production                                          0.454373
# Japan_Industrial_Production_Mom                                     -0.011233
# Japan_Inflation_Rate                                                -0.009617
# Japan_Interest_Rate                                                  0.201151
# Japan_Steel_Production                                               0.405718
# Switzerland_Core_Inflation_Rate                                      0.118820
# Switzerland_Exports                                                 -0.160894
# Switzerland_Inflation_Rate                                           0.320570
# Switzerland_Interest_Rate                                            0.179666
# United_Kingdom_Core_Inflation_Rate                                   0.397300
# United_Kingdom_Exports                                              -0.244468
# United_Kingdom_Industrial_Production                                -0.219396
# United_Kingdom_Industrial_Production_Mom                            -0.128486
# United_Kingdom_Inflation_Rate                                        0.525551
# United_Kingdom_Interest_Rate                                        -0.049382
# United_States_Core_Inflation_Rate                                   -0.010851
# United_States_Exports                                                0.001459
# United_States_Industrial_Production                                  1.000000
# United_States_Industrial_Production_Mom                              0.254577
# United_States_Inflation_Rate                                         0.357238
# United_States_Steel_Production                                       0.473721
#
#                                           United_States_Industrial_Production_Mom  \
# China_Core_Inflation_Rate                                                0.004236
# China_Exports                                                           -0.012998
# China_GDP                                                               -0.304388
# China_Industrial_Production                                              0.171938
# China_Industrial_Production_Mom                                          0.074491
# China_Inflation_Rate                                                     0.082164
# China_Interest_Rate                                                     -0.071090
# China_Steel_Production                                                   0.051236
# France_Core_Inflation_Rate                                              -0.001930
# France_Exports                                                          -0.113626
# France_Industrial_Production                                            -0.063027
# France_Industrial_Production_Mom                                         0.108613
# France_Inflation_Rate                                                    0.078403
# France_Interest_Rate                                                    -0.032630
# Germany_Core_Inflation_Rate                                             -0.126397
# Germany_Exports                                                         -0.078152
# Germany_Industrial_Production                                            0.106140
# Germany_Industrial_Production_Mom                                        0.194874
# Germany_Inflation_Rate                                                   0.015642
# Germany_Interest_Rate                                                   -0.032630
# Germany_Steel_Production                                                 0.028749
# Italy_Core_Inflation_Rate                                                0.027600
# Italy_Exports                                                           -0.035369
# Italy_Industrial_Production                                              0.027091
# Italy_Industrial_Production_Mom                                          0.091593
# Italy_Inflation_Rate                                                     0.094745
# Italy_Interest_Rate                                                     -0.032630
# Japan_Core_Inflation_Rate                                               -0.107456
# Japan_Exports                                                           -0.031448
# Japan_Industrial_Production                                             -0.023790
# Japan_Industrial_Production_Mom                                          0.162911
# Japan_Inflation_Rate                                                    -0.112615
# Japan_Interest_Rate                                                     -0.024360
# Japan_Steel_Production                                                   0.005680
# Switzerland_Core_Inflation_Rate                                         -0.007848
# Switzerland_Exports                                                     -0.033908
# Switzerland_Inflation_Rate                                               0.041308
# Switzerland_Interest_Rate                                                0.028560
# United_Kingdom_Core_Inflation_Rate                                       0.079992
# United_Kingdom_Exports                                                  -0.046979
# United_Kingdom_Industrial_Production                                     0.022841
# United_Kingdom_Industrial_Production_Mom                                 0.177491
# United_Kingdom_Inflation_Rate                                            0.132156
# United_Kingdom_Interest_Rate                                            -0.177810
# United_States_Core_Inflation_Rate                                       -0.069672
# United_States_Exports                                                   -0.056593
# United_States_Industrial_Production                                      0.254577
# United_States_Industrial_Production_Mom                                  1.000000
# United_States_Inflation_Rate                                             0.121929
# United_States_Steel_Production                                           0.028333
#
#                                           United_States_Inflation_Rate  \
# China_Core_Inflation_Rate                                    -0.203296
# China_Exports                                                 0.491679
# China_GDP                                                     0.550985
# China_Industrial_Production                                  -0.232295
# China_Industrial_Production_Mom                              -0.183883
# China_Inflation_Rate                                         -0.142046
# China_Interest_Rate                                          -0.632366
# China_Steel_Production                                        0.344398
# France_Core_Inflation_Rate                                    0.687309
# France_Exports                                                0.580744
# France_Industrial_Production                                  0.119369
# France_Industrial_Production_Mom                             -0.065578
# France_Inflation_Rate                                         0.840090
# France_Interest_Rate                                          0.259303
# Germany_Core_Inflation_Rate                                   0.561123
# Germany_Exports                                               0.577641
# Germany_Industrial_Production                                -0.074554
# Germany_Industrial_Production_Mom                            -0.076060
# Germany_Inflation_Rate                                        0.893090
# Germany_Interest_Rate                                         0.259303
# Germany_Steel_Production                                     -0.296910
# Italy_Core_Inflation_Rate                                     0.554785
# Italy_Exports                                                 0.556313
# Italy_Industrial_Production                                   0.014321
# Italy_Industrial_Production_Mom                              -0.109245
# Italy_Inflation_Rate                                          0.718172
# Italy_Interest_Rate                                           0.259303
# Japan_Core_Inflation_Rate                                     0.419005
# Japan_Exports                                                 0.522990
# Japan_Industrial_Production                                   0.045581
# Japan_Industrial_Production_Mom                              -0.005858
# Japan_Inflation_Rate                                          0.374519
# Japan_Interest_Rate                                          -0.217720
# Japan_Steel_Production                                       -0.413870
# Switzerland_Core_Inflation_Rate                               0.658529
# Switzerland_Exports                                           0.605267
# Switzerland_Inflation_Rate                                    0.779541
# Switzerland_Interest_Rate                                     0.335251
# United_Kingdom_Core_Inflation_Rate                            0.767646
# United_Kingdom_Exports                                        0.580943
# United_Kingdom_Industrial_Production                         -0.452426
# United_Kingdom_Industrial_Production_Mom                     -0.140052
# United_Kingdom_Inflation_Rate                                 0.742927
# United_Kingdom_Interest_Rate                                  0.358368
# United_States_Core_Inflation_Rate                             0.711484
# United_States_Exports                                         0.625449
# United_States_Industrial_Production                           0.357238
# United_States_Industrial_Production_Mom                       0.121929
# United_States_Inflation_Rate                                  1.000000
# United_States_Steel_Production                                0.180989
#
#                                           United_States_Steel_Production
# China_Core_Inflation_Rate                                       0.346979
# China_Exports                                                  -0.088536
# China_GDP                                                      -0.175000
# China_Industrial_Production                                     0.212601
# China_Industrial_Production_Mom                                -0.031805
# China_Inflation_Rate                                            0.358545
# China_Interest_Rate                                             0.397936
# China_Steel_Production                                         -0.123561
# France_Core_Inflation_Rate                                     -0.015814
# France_Exports                                                 -0.117215
# France_Industrial_Production                                   -0.037797
# France_Industrial_Production_Mom                               -0.078710
# France_Inflation_Rate                                           0.190830
# France_Interest_Rate                                           -0.067200
# Germany_Core_Inflation_Rate                                     0.012610
# Germany_Exports                                                -0.175706
# Germany_Industrial_Production                                   0.096253
# Germany_Industrial_Production_Mom                              -0.075595
# Germany_Inflation_Rate                                          0.181159
# Germany_Interest_Rate                                          -0.067200
# Germany_Steel_Production                                        0.335167
# Italy_Core_Inflation_Rate                                       0.008793
# Italy_Exports                                                  -0.182412
# Italy_Industrial_Production                                    -0.097620
# Italy_Industrial_Production_Mom                                -0.120031
# Italy_Inflation_Rate                                            0.210353
# Italy_Interest_Rate                                            -0.067200
# Japan_Core_Inflation_Rate                                       0.085675
# Japan_Exports                                                  -0.153223
# Japan_Industrial_Production                                     0.141838
# Japan_Industrial_Production_Mom                                -0.074373
# Japan_Inflation_Rate                                           -0.007979
# Japan_Interest_Rate                                             0.113062
# Japan_Steel_Production                                          0.475448
# Switzerland_Core_Inflation_Rate                                -0.023450
# Switzerland_Exports                                            -0.149679
# Switzerland_Inflation_Rate                                      0.061153
# Switzerland_Interest_Rate                                      -0.026135
# United_Kingdom_Core_Inflation_Rate                              0.015664
# United_Kingdom_Exports                                         -0.174067
# United_Kingdom_Industrial_Production                            0.062067
# United_Kingdom_Industrial_Production_Mom                       -0.059440
# United_Kingdom_Inflation_Rate                                   0.136459
# United_Kingdom_Interest_Rate                                    0.047262
# United_States_Core_Inflation_Rate                               0.032484
# United_States_Exports                                           0.053801
# United_States_Industrial_Production                             0.473721
# United_States_Industrial_Production_Mom                         0.028333
# United_States_Inflation_Rate                                    0.180989
# United_States_Steel_Production                                  1.000000
#
# [50 rows x 50 columns]

# %%
#creating correlation matrix to facilitate interpretation
def cor_heatmap(cor):
    
    #setting the figure size
    plt.figure(figsize=(12, 10))

    #creating a mask for the upper triangle of the matrix (to avoid plotting duplicate correlation values)
    mask = np.triu(np.ones_like(cor, dtype=bool))

    #plotting the correlation heatmap
    sns.heatmap(
        data=cor,                 #correlation matrix input
        mask=mask,                #applying upper-triangle mask
        annot=True,               #displaying correlation coefficients
        cmap=sns.light_palette("#798a40", as_cmap=True), #color map for visual contrast
        fmt='.2f',                #formatting values to two decimals
        square=True,              #ensuring square-shaped cells
        linewidths=0.5,           #adding grid lines between cells
        cbar_kws={"shrink": 0.8}  #adjusting color bar size
    )

    #adding a title and display the plot
    plt.title("Spearman Correlation Matrix", fontsize=14)
    plt.show()

# %%
#applying the function to our numerical features
cor_heatmap(cor_spearman)

# %% [markdown]
# ## 4. Data Preparation

# %% [markdown]
# ### 4.1. Handling Missing Values

# %% [markdown]
# - For columns with >50% missing values (corresponding to GDP columns), we have decided to fill the missing observations with the value of the GDP of that year.
# - For columns with <50% missing values, interpolation is going to be applied in order to fill them.
# - Columns whose missing values reach 100% in positive months (corresponding to steel production of some countries), we have decided to drop those columns, since it does not contain relevant information that could be used in the model later on.

# %%
# columns to drop - steel production countries with 100% missing in periods 1-48
cols_to_drop = [
    'France_Steel_Production',
    'Italy_Steel_Production',
    'United_Kingdom_Steel_Production'
]
df_market = df_market.drop(columns=cols_to_drop)

# identify GDP columns (more than 50% missing) vs other columns
missing_pct = df_market.isna().sum() / len(df_market) * 100
gdp_cols    = missing_pct[missing_pct > 50].index.tolist()
other_cols  = missing_pct[(missing_pct > 0) & (missing_pct <= 50)].index.tolist()

print("GDP columns to forward-fill:", gdp_cols)
print("Other columns to interpolate:", other_cols)

# forward-fill GDP columns, then backward-fill any remaining NaNs at the start
df_market = df_market.sort_values('Period').reset_index(drop=True)
df_market[gdp_cols] = df_market[gdp_cols].ffill().bfill()

# linear interpolation for columns with less than 50% missing + ffill/bfill for edges
df_market[other_cols] = df_market[other_cols].interpolate(method='linear').ffill().bfill()

# verify no missing values remain
remaining = df_market.isna().sum()
remaining = remaining[remaining > 0]
print("\nRemaining missing values:")
print(remaining if len(remaining) > 0 else "None - all clean!")
# Out:
# GDP columns to forward-fill: ['China_GDP', 'China_GDP_from_Construction', 'China_GDP_from_Manufacturing', 'France_GDP', 'France_GDP_from_Construction', 'France_GDP_from_Manufacturing', 'Germany_GDP', 'Germany_GDP_from_Construction', 'Germany_GDP_from_Manufacturing', 'Italy_GDP', 'Italy_GDP_from_Construction', 'Italy_GDP_from_Manufacturing', 'Japan_GDP', 'Japan_GDP_from_Construction', 'Japan_GDP_from_Manufacturing', 'Switzerland_GDP', 'Switzerland_Industrial_Production', 'Switzerland_Industrial_Production_Mom', 'United_Kingdom_GDP', 'United_Kingdom_GDP_from_Construction', 'United_Kingdom_GDP_from_Manufacturing', 'United_States_GDP', 'United_States_GDP_from_Construction', 'United_States_GDP_from_Manufacturing']
# Other columns to interpolate: ['China_Core_Inflation_Rate', 'China_Exports', 'China_Industrial_Production', 'China_Industrial_Production_Mom', 'China_Inflation_Rate', 'China_Interest_Rate', 'France_Core_Inflation_Rate', 'France_Exports', 'France_Industrial_Production', 'France_Industrial_Production_Mom', 'France_Inflation_Rate', 'France_Interest_Rate', 'Germany_Core_Inflation_Rate', 'Germany_Exports', 'Germany_Industrial_Production', 'Germany_Industrial_Production_Mom', 'Germany_Inflation_Rate', 'Germany_Interest_Rate', 'Italy_Core_Inflation_Rate', 'Italy_Exports', 'Italy_Industrial_Production', 'Italy_Industrial_Production_Mom', 'Italy_Inflation_Rate', 'Italy_Interest_Rate', 'Japan_Core_Inflation_Rate', 'Japan_Exports', 'Japan_Industrial_Production', 'Japan_Industrial_Production_Mom', 'Japan_Inflation_Rate', 'Japan_Interest_Rate', 'Switzerland_Core_Inflation_Rate', 'Switzerland_Exports', 'Switzerland_Inflation_Rate', 'Switzerland_Interest_Rate', 'United_Kingdom_Core_Inflation_Rate', 'United_Kingdom_Exports', 'United_Kingdom_Industrial_Production', 'United_Kingdom_Industrial_Production_Mom', 'United_Kingdom_Inflation_Rate', 'United_Kingdom_Interest_Rate', 'United_States_Core_Inflation_Rate', 'United_States_Exports', 'United_States_Industrial_Production', 'United_States_Industrial_Production_Mom', 'United_States_Inflation_Rate', 'United_States_Interest_Rate']
#
# Remaining missing values:
# None - all clean!

# %%
#checking number of missing values
df_market.isna().sum()
# Out:
# Period                                      0
# China_Core_Inflation_Rate                   0
# China_Exports                               0
# China_GDP                                   0
# China_GDP_from_Construction                 0
# China_GDP_from_Manufacturing                0
# China_Industrial_Production                 0
# China_Industrial_Production_Mom             0
# China_Inflation_Rate                        0
# China_Interest_Rate                         0
# China_Steel_Production                      0
# France_Core_Inflation_Rate                  0
# France_Exports                              0
# France_GDP                                  0
# France_GDP_from_Construction                0
# France_GDP_from_Manufacturing               0
# France_Industrial_Production                0
# France_Industrial_Production_Mom            0
# France_Inflation_Rate                       0
# France_Interest_Rate                        0
# Germany_Core_Inflation_Rate                 0
# Germany_Exports                             0
# Germany_GDP                                 0
# Germany_GDP_from_Construction               0
# Germany_GDP_from_Manufacturing              0
# Germany_Industrial_Production               0
# Germany_Industrial_Production_Mom           0
# Germany_Inflation_Rate                      0
# Germany_Interest_Rate                       0
# Germany_Steel_Production                    0
# Italy_Core_Inflation_Rate                   0
# Italy_Exports                               0
# Italy_GDP                                   0
# Italy_GDP_from_Construction                 0
# Italy_GDP_from_Manufacturing                0
# Italy_Industrial_Production                 0
# Italy_Industrial_Production_Mom             0
# Italy_Inflation_Rate                        0
# Italy_Interest_Rate                         0
# Japan_Core_Inflation_Rate                   0
# Japan_Exports                               0
# Japan_GDP                                   0
# Japan_GDP_from_Construction                 0
# Japan_GDP_from_Manufacturing                0
# Japan_Industrial_Production                 0
# Japan_Industrial_Production_Mom             0
# Japan_Inflation_Rate                        0
# Japan_Interest_Rate                         0
# Japan_Steel_Production                      0
# Switzerland_Core_Inflation_Rate             0
# Switzerland_Exports                         0
# Switzerland_GDP                             0
# Switzerland_Industrial_Production           0
# Switzerland_Industrial_Production_Mom       0
# Switzerland_Inflation_Rate                  0
# Switzerland_Interest_Rate                   0
# United_Kingdom_Core_Inflation_Rate          0
# United_Kingdom_Exports                      0
# United_Kingdom_GDP                          0
# United_Kingdom_GDP_from_Construction        0
# United_Kingdom_GDP_from_Manufacturing       0
# United_Kingdom_Industrial_Production        0
# United_Kingdom_Industrial_Production_Mom    0
# United_Kingdom_Inflation_Rate               0
# United_Kingdom_Interest_Rate                0
# United_States_Core_Inflation_Rate           0
# United_States_Exports                       0
# United_States_GDP                           0
# United_States_GDP_from_Construction         0
# United_States_GDP_from_Manufacturing        0
# United_States_Industrial_Production         0
# United_States_Industrial_Production_Mom     0
# United_States_Inflation_Rate                0
# United_States_Interest_Rate                 0
# United_States_Steel_Production              0
# dtype: int64

# %% [markdown]
# ### 4.2. Merging Datasets

# %%
#merging the datasets on the left
df_merged = train_data.merge(df_market, on='Period', how='left')

print(df_merged.shape)
# Out:
# (4237, 81)

# %%
df_merged.head(25)
# Out:
#     Period Biz_Desc Business_Unit   Segment Subsegment  Orders  Revenue  \
# 0        1      SSI        SSI027  SSI02710   SSI02710       0  -390277
# 1        2      SSI        SSI027  SSI02710   SSI02710       0      334
# 2        3      SSI        SSI027  SSI02710   SSI02710       0      334
# 3        4      SSI        SSI027  SSI02710   SSI02710       0  1811758
# 4        5      SSI        SSI027  SSI02710   SSI02710       0    80112
# 5        6      SSI        SSI027  SSI02710   SSI02710       0    38468
# 6        7      SSI        SSI027  SSI02710   SSI02710       0      334
# 7        8      SSI        SSI027  SSI02710   SSI02710       0      334
# 8        9      SSI        SSI027  SSI02710   SSI02710       0   -37173
# 9       10      SSI        SSI027  SSI02710   SSI02710       0    38094
# 10      11      SSI        SSI027  SSI02710   SSI02710       0      334
# 11      12      SSI        SSI027  SSI02710   SSI02710       0      334
# 12      13      SSI        SSI027  SSI02710   SSI02710       0      334
# 13      14      SSI        SSI027  SSI02710   SSI02710       0      334
# 14      15      SSI        SSI027  SSI02710   SSI02710       0      334
# 15      16      SSI        SSI027  SSI02710   SSI02710       0      334
# 16      17      SSI        SSI027  SSI02710   SSI02710       0      334
# 17      18      SSI        SSI027  SSI02710   SSI02710       0      334
# 18      19      SSI        SSI027  SSI02710   SSI02710       0      334
# 19      20      SSI        SSI027  SSI02710   SSI02710       0      334
# 20      21      SSI        SSI027  SSI02710   SSI02710       0      334
# 21      22      SSI        SSI027  SSI02710   SSI02710       0      334
# 22      23      SSI        SSI027  SSI02710   SSI02710       0      334
# 23      24      SSI        SSI027  SSI02710   SSI02710       0      334
# 24      25      SSI        SSI027  SSI02710   SSI02710       0      334
#
#     China_Core_Inflation_Rate  China_Exports  China_GDP  ...  \
# 0                         0.7         263.09   14996.41  ...
# 1                         0.9         263.23   14996.41  ...
# 2                         0.9         280.30   14996.41  ...
# 3                         1.3         281.28   14996.41  ...
# 4                         1.2         293.17   14996.41  ...
# 5                         1.2         304.70   14996.41  ...
# 6                         1.3         299.12   14996.41  ...
# 7                         1.2         324.28   14996.41  ...
# 8                         1.2         339.66   18201.70  ...
# 9                         1.2         323.28   18201.70  ...
# 10                        1.1         214.80   18201.70  ...
# 11                        1.1         272.87   18201.70  ...
# 12                        0.9         268.97   18201.70  ...
# 13                        0.9         303.90   18201.70  ...
# 14                        1.0         323.41   18201.70  ...
# 15                        0.8         327.46   18201.70  ...
# 16                        0.8         310.39   18201.70  ...
# 17                        0.6         318.24   18201.70  ...
# 18                        0.6         293.61   18201.70  ...
# 19                        0.6         290.62   18201.70  ...
# 20                        0.7         296.90   18316.77  ...
# 21                        1.0         284.41   18316.77  ...
# 22                        0.6         208.64   18316.77  ...
# 23                        0.7         302.45   18316.77  ...
# 24                        0.7         288.08   18316.77  ...
#
#     United_States_Core_Inflation_Rate  United_States_Exports  \
# 0                                 3.0                209.117
# 1                                 3.8                211.641
# 2                                 4.5                214.009
# 3                                 4.3                216.286
# 4                                 4.0                217.728
# 5                                 4.0                214.183
# 6                                 4.6                228.772
# 7                                 4.9                231.756
# 8                                 5.5                236.793
# 9                                 6.0                232.637
# 10                                6.4                237.005
# 11                                6.5                248.299
# 12                                6.2                256.715
# 13                                6.0                259.050
# 14                                5.9                262.615
# 15                                5.9                265.032
# 16                                6.3                265.216
# 17                                6.6                262.473
# 18                                6.3                259.671
# 19                                6.0                256.225
# 20                                5.7                253.508
# 21                                5.6                259.974
# 22                                5.5                254.337
# 23                                5.6                259.541
# 24                                5.5                253.608
#
#     United_States_GDP  United_States_GDP_from_Construction  \
# 0            21354.11                                892.8
# 1            21354.11                                892.8
# 2            21354.11                                904.4
# 3            21354.11                                904.4
# 4            21354.11                                904.4
# 5            21354.11                                886.3
# 6            21354.11                                886.3
# 7            21354.11                                886.3
# 8            23681.17                                866.9
# 9            23681.17                                866.9
# 10           23681.17                                866.9
# 11           23681.17                                884.3
# 12           23681.17                                884.3
# 13           23681.17                                884.3
# 14           23681.17                                851.7
# 15           23681.17                                851.7
# 16           23681.17                                851.7
# 17           23681.17                                813.5
# 18           23681.17                                813.5
# 19           23681.17                                813.5
# 20           26006.89                                806.3
# 21           26006.89                                806.3
# 22           26006.89                                806.3
# 23           26006.89                                810.8
# 24           26006.89                                810.8
#
#     United_States_GDP_from_Manufacturing  United_States_Industrial_Production  \
# 0                                 2247.8                                 16.1
# 1                                 2247.8                                 15.3
# 2                                 2275.1                                  8.7
# 3                                 2275.1                                  5.3
# 4                                 2275.1                                  4.3
# 5                                 2276.0                                  3.2
# 6                                 2276.0                                  4.0
# 7                                 2276.0                                  4.5
# 8                                 2358.9                                  3.0
# 9                                 2358.9                                  2.4
# 10                                2358.9                                  6.6
# 11                                2327.8                                  4.6
# 12                                2327.8                                  4.6
# 13                                2327.8                                  3.8
# 14                                2301.1                                  3.2
# 15                                2301.1                                  3.0
# 16                                2301.1                                  3.1
# 17                                2302.4                                  4.6
# 18                                2302.4                                  3.1
# 19                                2302.4                                  0.1
# 20                                2274.6                                 -0.8
# 21                                2274.6                                  0.3
# 22                                2274.6                                 -0.2
# 23                                2224.4                                 -0.4
# 24                                2224.4                                 -0.2
#
#     United_States_Industrial_Production_Mom  United_States_Inflation_Rate  \
# 0                                       0.1                           4.2
# 1                                       0.9                           5.0
# 2                                       0.5                           5.4
# 3                                       0.4                           5.4
# 4                                       0.0                           5.3
# 5                                      -1.0                           5.4
# 6                                       1.4                           6.2
# 7                                       0.9                           6.8
# 8                                      -0.1                           7.0
# 9                                       0.0                           7.5
# 10                                      0.6                           7.9
# 11                                      0.8                           8.5
# 12                                      0.2                           8.3
# 13                                      0.1                           8.6
# 14                                     -0.1                           9.1
# 15                                      0.2                           8.5
# 16                                      0.1                           8.3
# 17                                      0.4                           8.2
# 18                                     -0.1                           7.7
# 19                                     -0.3                           7.1
# 20                                     -1.2                           6.5
# 21                                      0.7                           6.4
# 22                                      0.1                           6.0
# 23                                      0.4                           5.0
# 24                                      0.2                           4.9
#
#     United_States_Interest_Rate  United_States_Steel_Production
# 0                          0.25                          6900.0
# 1                          0.25                          7200.0
# 2                          0.25                          7100.0
# 3                          0.25                          7500.0
# 4                          0.25                          7500.0
# 5                          0.25                          7300.0
# 6                          0.25                          7500.0
# 7                          0.25                          7200.0
# 8                          0.25                          7200.0
# 9                          0.25                          7300.0
# 10                         0.25                          6400.0
# 11                         0.50                          7000.0
# 12                         0.50                          6900.0
# 13                         1.00                          7200.0
# 14                         1.75                          6900.0
# 15                         2.50                          7000.0
# 16                         2.50                          7000.0
# 17                         3.25                          6600.0
# 18                         3.25                          6700.0
# 19                         4.00                          6400.0
# 20                         4.50                          6500.0
# 21                         4.50                          6500.0
# 22                         4.75                          6000.0
# 23                         5.00                          6700.0
# 24                         5.00                          6600.0
#
# [25 rows x 81 columns]

# %%
df_merged.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4237 entries, 0 to 4236
# Data columns (total 81 columns):
#  #   Column                                    Non-Null Count  Dtype
# ---  ------                                    --------------  -----
#  0   Period                                    4237 non-null   Int32
#  1   Biz_Desc                                  4237 non-null   object
#  2   Business_Unit                             4237 non-null   object
#  3   Segment                                   4237 non-null   object
#  4   Subsegment                                4237 non-null   object
#  5   Orders                                    4237 non-null   Int32
#  6   Revenue                                   4237 non-null   Int32
#  7   China_Core_Inflation_Rate                 4237 non-null   float64
#  8   China_Exports                             4237 non-null   float64
#  9   China_GDP                                 4237 non-null   float64
#  10  China_GDP_from_Construction               4237 non-null   float64
#  11  China_GDP_from_Manufacturing              4237 non-null   float64
#  12  China_Industrial_Production               4237 non-null   float64
#  13  China_Industrial_Production_Mom           4237 non-null   float64
#  14  China_Inflation_Rate                      4237 non-null   float64
#  15  China_Interest_Rate                       4237 non-null   float64
#  16  China_Steel_Production                    4237 non-null   int64
#  17  France_Core_Inflation_Rate                4237 non-null   float64
#  18  France_Exports                            4237 non-null   float64
#  19  France_GDP                                4237 non-null   float64
#  20  France_GDP_from_Construction              4237 non-null   float64
#  21  France_GDP_from_Manufacturing             4237 non-null   float64
#  22  France_Industrial_Production              4237 non-null   float64
#  23  France_Industrial_Production_Mom          4237 non-null   float64
#  24  France_Inflation_Rate                     4237 non-null   float64
#  25  France_Interest_Rate                      4237 non-null   float64
#  26  Germany_Core_Inflation_Rate               4237 non-null   float64
#  27  Germany_Exports                           4237 non-null   float64
#  28  Germany_GDP                               4237 non-null   float64
#  29  Germany_GDP_from_Construction             4237 non-null   float64
#  30  Germany_GDP_from_Manufacturing            4237 non-null   float64
#  31  Germany_Industrial_Production             4237 non-null   float64
#  32  Germany_Industrial_Production_Mom         4237 non-null   float64
#  33  Germany_Inflation_Rate                    4237 non-null   float64
#  34  Germany_Interest_Rate                     4237 non-null   float64
#  35  Germany_Steel_Production                  4237 non-null   float64
#  36  Italy_Core_Inflation_Rate                 4237 non-null   float64
#  37  Italy_Exports                             4237 non-null   float64
#  38  Italy_GDP                                 4237 non-null   float64
#  39  Italy_GDP_from_Construction               4237 non-null   float64
#  40  Italy_GDP_from_Manufacturing              4237 non-null   float64
#  41  Italy_Industrial_Production               4237 non-null   float64
#  42  Italy_Industrial_Production_Mom           4237 non-null   float64
#  43  Italy_Inflation_Rate                      4237 non-null   float64
#  44  Italy_Interest_Rate                       4237 non-null   float64
#  45  Japan_Core_Inflation_Rate                 4237 non-null   float64
#  46  Japan_Exports                             4237 non-null   float64
#  47  Japan_GDP                                 4237 non-null   float64
#  48  Japan_GDP_from_Construction               4237 non-null   float64
#  49  Japan_GDP_from_Manufacturing              4237 non-null   float64
#  50  Japan_Industrial_Production               4237 non-null   float64
#  51  Japan_Industrial_Production_Mom           4237 non-null   float64
#  52  Japan_Inflation_Rate                      4237 non-null   float64
#  53  Japan_Interest_Rate                       4237 non-null   float64
#  54  Japan_Steel_Production                    4237 non-null   float64
#  55  Switzerland_Core_Inflation_Rate           4237 non-null   float64
#  56  Switzerland_Exports                       4237 non-null   float64
#  57  Switzerland_GDP                           4237 non-null   float64
#  58  Switzerland_Industrial_Production         4237 non-null   float64
#  59  Switzerland_Industrial_Production_Mom     4237 non-null   float64
#  60  Switzerland_Inflation_Rate                4237 non-null   float64
#  61  Switzerland_Interest_Rate                 4237 non-null   float64
#  62  United_Kingdom_Core_Inflation_Rate        4237 non-null   float64
#  63  United_Kingdom_Exports                    4237 non-null   float64
#  64  United_Kingdom_GDP                        4237 non-null   float64
#  65  United_Kingdom_GDP_from_Construction      4237 non-null   float64
#  66  United_Kingdom_GDP_from_Manufacturing     4237 non-null   float64
#  67  United_Kingdom_Industrial_Production      4237 non-null   float64
#  68  United_Kingdom_Industrial_Production_Mom  4237 non-null   float64
#  69  United_Kingdom_Inflation_Rate             4237 non-null   float64
#  70  United_Kingdom_Interest_Rate              4237 non-null   float64
#  71  United_States_Core_Inflation_Rate         4237 non-null   float64
#  72  United_States_Exports                     4237 non-null   float64
#  73  United_States_GDP                         4237 non-null   float64
#  74  United_States_GDP_from_Construction       4237 non-null   float64
#  75  United_States_GDP_from_Manufacturing      4237 non-null   float64
#  76  United_States_Industrial_Production       4237 non-null   float64
#  77  United_States_Industrial_Production_Mom   4237 non-null   float64
#  78  United_States_Inflation_Rate              4237 non-null   float64
#  79  United_States_Interest_Rate               4237 non-null   float64
#  80  United_States_Steel_Production            4237 non-null   float64
# dtypes: Int32(3), float64(73), int64(1), object(4)
# memory usage: 2.6+ MB

# %%
#checking missing values after merging 
pd.set_option('display.max_rows', None)
df_merged.isna().sum()/len(df_merged) * 100
# Out:
# Period                                      0.0
# Biz_Desc                                    0.0
# Business_Unit                               0.0
# Segment                                     0.0
# Subsegment                                  0.0
# Orders                                      0.0
# Revenue                                     0.0
# China_Core_Inflation_Rate                   0.0
# China_Exports                               0.0
# China_GDP                                   0.0
# China_GDP_from_Construction                 0.0
# China_GDP_from_Manufacturing                0.0
# China_Industrial_Production                 0.0
# China_Industrial_Production_Mom             0.0
# China_Inflation_Rate                        0.0
# China_Interest_Rate                         0.0
# China_Steel_Production                      0.0
# France_Core_Inflation_Rate                  0.0
# France_Exports                              0.0
# France_GDP                                  0.0
# France_GDP_from_Construction                0.0
# France_GDP_from_Manufacturing               0.0
# France_Industrial_Production                0.0
# France_Industrial_Production_Mom            0.0
# France_Inflation_Rate                       0.0
# France_Interest_Rate                        0.0
# Germany_Core_Inflation_Rate                 0.0
# Germany_Exports                             0.0
# Germany_GDP                                 0.0
# Germany_GDP_from_Construction               0.0
# Germany_GDP_from_Manufacturing              0.0
# Germany_Industrial_Production               0.0
# Germany_Industrial_Production_Mom           0.0
# Germany_Inflation_Rate                      0.0
# Germany_Interest_Rate                       0.0
# Germany_Steel_Production                    0.0
# Italy_Core_Inflation_Rate                   0.0
# Italy_Exports                               0.0
# Italy_GDP                                   0.0
# Italy_GDP_from_Construction                 0.0
# Italy_GDP_from_Manufacturing                0.0
# Italy_Industrial_Production                 0.0
# Italy_Industrial_Production_Mom             0.0
# Italy_Inflation_Rate                        0.0
# Italy_Interest_Rate                         0.0
# Japan_Core_Inflation_Rate                   0.0
# Japan_Exports                               0.0
# Japan_GDP                                   0.0
# Japan_GDP_from_Construction                 0.0
# Japan_GDP_from_Manufacturing                0.0
# Japan_Industrial_Production                 0.0
# Japan_Industrial_Production_Mom             0.0
# Japan_Inflation_Rate                        0.0
# Japan_Interest_Rate                         0.0
# Japan_Steel_Production                      0.0
# Switzerland_Core_Inflation_Rate             0.0
# Switzerland_Exports                         0.0
# Switzerland_GDP                             0.0
# Switzerland_Industrial_Production           0.0
# Switzerland_Industrial_Production_Mom       0.0
# Switzerland_Inflation_Rate                  0.0
# Switzerland_Interest_Rate                   0.0
# United_Kingdom_Core_Inflation_Rate          0.0
# United_Kingdom_Exports                      0.0
# United_Kingdom_GDP                          0.0
# United_Kingdom_GDP_from_Construction        0.0
# United_Kingdom_GDP_from_Manufacturing       0.0
# United_Kingdom_Industrial_Production        0.0
# United_Kingdom_Industrial_Production_Mom    0.0
# United_Kingdom_Inflation_Rate               0.0
# United_Kingdom_Interest_Rate                0.0
# United_States_Core_Inflation_Rate           0.0
# United_States_Exports                       0.0
# United_States_GDP                           0.0
# United_States_GDP_from_Construction         0.0
# United_States_GDP_from_Manufacturing        0.0
# United_States_Industrial_Production         0.0
# United_States_Industrial_Production_Mom     0.0
# United_States_Inflation_Rate                0.0
# United_States_Interest_Rate                 0.0
# United_States_Steel_Production              0.0
# dtype: float64

# %%
# add real dates from period map
df_period_map = df_period_map.dropna(subset=['Period'])
df_period_map['Period'] = df_period_map['Period'].astype(int)
df_merged = df_merged.merge(df_period_map[['Period', 'DATE']], on='Period', how='left')
df_merged = df_merged.rename(columns={'DATE': 'Date'})

print(df_merged[['Period', 'Date']].drop_duplicates().head(10))
# Out:
#    Period       Date
# 0       1 2021-04-01
# 1       2 2021-05-01
# 2       3 2021-06-01
# 3       4 2021-07-01
# 4       5 2021-08-01
# 5       6 2021-09-01
# 6       7 2021-10-01
# 7       8 2021-11-01
# 8       9 2021-12-01
# 9      10 2022-01-01

# %%
df_merged.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4237 entries, 0 to 4236
# Data columns (total 82 columns):
#  #   Column                                    Non-Null Count  Dtype
# ---  ------                                    --------------  -----
#  0   Period                                    4237 non-null   Int32
#  1   Biz_Desc                                  4237 non-null   object
#  2   Business_Unit                             4237 non-null   object
#  3   Segment                                   4237 non-null   object
#  4   Subsegment                                4237 non-null   object
#  5   Orders                                    4237 non-null   Int32
#  6   Revenue                                   4237 non-null   Int32
#  7   China_Core_Inflation_Rate                 4237 non-null   float64
#  8   China_Exports                             4237 non-null   float64
#  9   China_GDP                                 4237 non-null   float64
#  10  China_GDP_from_Construction               4237 non-null   float64
#  11  China_GDP_from_Manufacturing              4237 non-null   float64
#  12  China_Industrial_Production               4237 non-null   float64
#  13  China_Industrial_Production_Mom           4237 non-null   float64
#  14  China_Inflation_Rate                      4237 non-null   float64
#  15  China_Interest_Rate                       4237 non-null   float64
#  16  China_Steel_Production                    4237 non-null   int64
#  17  France_Core_Inflation_Rate                4237 non-null   float64
#  18  France_Exports                            4237 non-null   float64
#  19  France_GDP                                4237 non-null   float64
#  20  France_GDP_from_Construction              4237 non-null   float64
#  21  France_GDP_from_Manufacturing             4237 non-null   float64
#  22  France_Industrial_Production              4237 non-null   float64
#  23  France_Industrial_Production_Mom          4237 non-null   float64
#  24  France_Inflation_Rate                     4237 non-null   float64
#  25  France_Interest_Rate                      4237 non-null   float64
#  26  Germany_Core_Inflation_Rate               4237 non-null   float64
#  27  Germany_Exports                           4237 non-null   float64
#  28  Germany_GDP                               4237 non-null   float64
#  29  Germany_GDP_from_Construction             4237 non-null   float64
#  30  Germany_GDP_from_Manufacturing            4237 non-null   float64
#  31  Germany_Industrial_Production             4237 non-null   float64
#  32  Germany_Industrial_Production_Mom         4237 non-null   float64
#  33  Germany_Inflation_Rate                    4237 non-null   float64
#  34  Germany_Interest_Rate                     4237 non-null   float64
#  35  Germany_Steel_Production                  4237 non-null   float64
#  36  Italy_Core_Inflation_Rate                 4237 non-null   float64
#  37  Italy_Exports                             4237 non-null   float64
#  38  Italy_GDP                                 4237 non-null   float64
#  39  Italy_GDP_from_Construction               4237 non-null   float64
#  40  Italy_GDP_from_Manufacturing              4237 non-null   float64
#  41  Italy_Industrial_Production               4237 non-null   float64
#  42  Italy_Industrial_Production_Mom           4237 non-null   float64
#  43  Italy_Inflation_Rate                      4237 non-null   float64
#  44  Italy_Interest_Rate                       4237 non-null   float64
#  45  Japan_Core_Inflation_Rate                 4237 non-null   float64
#  46  Japan_Exports                             4237 non-null   float64
#  47  Japan_GDP                                 4237 non-null   float64
#  48  Japan_GDP_from_Construction               4237 non-null   float64
#  49  Japan_GDP_from_Manufacturing              4237 non-null   float64
#  50  Japan_Industrial_Production               4237 non-null   float64
#  51  Japan_Industrial_Production_Mom           4237 non-null   float64
#  52  Japan_Inflation_Rate                      4237 non-null   float64
#  53  Japan_Interest_Rate                       4237 non-null   float64
#  54  Japan_Steel_Production                    4237 non-null   float64
#  55  Switzerland_Core_Inflation_Rate           4237 non-null   float64
#  56  Switzerland_Exports                       4237 non-null   float64
#  57  Switzerland_GDP                           4237 non-null   float64
#  58  Switzerland_Industrial_Production         4237 non-null   float64
#  59  Switzerland_Industrial_Production_Mom     4237 non-null   float64
#  60  Switzerland_Inflation_Rate                4237 non-null   float64
#  61  Switzerland_Interest_Rate                 4237 non-null   float64
#  62  United_Kingdom_Core_Inflation_Rate        4237 non-null   float64
#  63  United_Kingdom_Exports                    4237 non-null   float64
#  64  United_Kingdom_GDP                        4237 non-null   float64
#  65  United_Kingdom_GDP_from_Construction      4237 non-null   float64
#  66  United_Kingdom_GDP_from_Manufacturing     4237 non-null   float64
#  67  United_Kingdom_Industrial_Production      4237 non-null   float64
#  68  United_Kingdom_Industrial_Production_Mom  4237 non-null   float64
#  69  United_Kingdom_Inflation_Rate             4237 non-null   float64
#  70  United_Kingdom_Interest_Rate              4237 non-null   float64
#  71  United_States_Core_Inflation_Rate         4237 non-null   float64
#  72  United_States_Exports                     4237 non-null   float64
#  73  United_States_GDP                         4237 non-null   float64
#  74  United_States_GDP_from_Construction       4237 non-null   float64
#  75  United_States_GDP_from_Manufacturing      4237 non-null   float64
#  76  United_States_Industrial_Production       4237 non-null   float64
#  77  United_States_Industrial_Production_Mom   4237 non-null   float64
#  78  United_States_Inflation_Rate              4237 non-null   float64
#  79  United_States_Interest_Rate               4237 non-null   float64
#  80  United_States_Steel_Production            4237 non-null   float64
#  81  Date                                      4237 non-null   datetime64[ns]
# dtypes: Int32(3), datetime64[ns](1), float64(73), int64(1), object(4)
# memory usage: 2.6+ MB

# %% [markdown]
# ## data

# %%
df_merged= pd.read_csv("df_merged_1.csv")

# %%
df_merged.head()
# Out:
#   Business_Unit   Segment Subsegment  Period Biz_Desc  Orders  Revenue  \
# 0        SSI027  SSI02710   SSI02710       1      SSI       0  -390277
# 1        SSI027  SSI02710   SSI02710       2      SSI       0      334
# 2        SSI027  SSI02710   SSI02710       3      SSI       0      334
# 3        SSI027  SSI02710   SSI02710       4      SSI       0  1811758
# 4        SSI027  SSI02710   SSI02710       5      SSI       0    80112
#
#    China_Core_Inflation_Rate  China_Exports  China_GDP  ...  \
# 0                        0.7         263.09   14996.41  ...
# 1                        0.9         263.23   14996.41  ...
# 2                        0.9         280.30   14996.41  ...
# 3                        1.3         281.28   14996.41  ...
# 4                        1.2         293.17   14996.41  ...
#
#    United_States_GDP_from_Construction  United_States_GDP_from_Manufacturing  \
# 0                                892.8                                2247.8
# 1                                892.8                                2247.8
# 2                                904.4                                2275.1
# 3                                904.4                                2275.1
# 4                                904.4                                2275.1
#
#    United_States_Industrial_Production  \
# 0                                 16.1
# 1                                 15.3
# 2                                  8.7
# 3                                  5.3
# 4                                  4.3
#
#    United_States_Industrial_Production_Mom  United_States_Inflation_Rate  \
# 0                                      0.1                           4.2
# 1                                      0.9                           5.0
# 2                                      0.5                           5.4
# 3                                      0.4                           5.4
# 4                                      0.0                           5.3
#
#    United_States_Interest_Rate  United_States_Steel_Production        Date  \
# 0                         0.25                          6900.0  2021-04-01
# 1                         0.25                          7200.0  2021-05-01
# 2                         0.25                          7100.0  2021-06-01
# 3                         0.25                          7500.0  2021-07-01
# 4                         0.25                          7500.0  2021-08-01
#
#    Start_Period  End_Period
# 0             1          36
# 1             1          36
# 2             1          36
# 3             1          36
# 4             1          36
#
# [5 rows x 84 columns]

# %% [markdown]
# ## EXPLORATORY DATA ANALYSIS

# %% [markdown]
# ### Trends and Seasonality

# %%
df_merged['Date'] = pd.to_datetime(df_merged['Date'])

# Aggregate revenue by date
ts = df_merged.groupby("Date")["Revenue"].sum().sort_index()

# Convert to monthly series
ts_monthly = ts.resample("MS").sum().interpolate()

# Extract seasonality
decomp = seasonal_decompose(ts_monthly, model="additive", period=12)

# Plot only the seasonal component
plt.figure(figsize=(12, 4))
plt.plot(decomp.seasonal)
plt.title("Revenue Seasonality")
plt.xlabel("Date")
plt.ylabel("Seasonal Effect")
plt.grid(True)
plt.show()

# %%
# Aggregate revenue by date
ts = df_merged.groupby("Date")["Revenue"].sum().sort_index()

# Convert to monthly series
ts_monthly = ts.resample("MS").sum()

# Average revenue by month
monthly_seasonality = ts_monthly.groupby(ts_monthly.index.month).mean()

# Plot seasonality by month
plt.figure(figsize=(10, 4))
plt.plot(monthly_seasonality.index, monthly_seasonality.values, marker="o")
plt.title("Average Revenue by Month")
plt.xlabel("Month")
plt.ylabel("Average Revenue")
plt.xticks(range(1, 13))
plt.grid(True)
plt.show()

# %% [markdown]
# The seazonality shows that march, september and december are higher revenue months and this seazonality does change throught the years.

# %% [markdown]
# ## Hierarquies porpotions

# %%
fig = px.sunburst(
    df_merged,
    path=["Business_Unit", "Segment", "Subsegment"],
    values="Revenue",
    title="Revenue Hierarchy: Business Unit > Segment > Subsegment"
)

fig.show()

# %% [markdown]
# ## Train Test Split

# %%
to_drop = ["Biz_Desc","Orders","Period"]
df_merged = df_merged.drop(columns=to_drop)

# %% [markdown]
# This code applies a rolling-origin cross-validation strategy to evaluate a time series
# forecasting model. The data are ordered chronologically, and successive folds are
# constructed using an expanding training window, a fixed forecasting horizon of
# 6 months, and a step size of 6 months.

# %%
# Sort data by date
df_merged = df_merged.sort_values("Date").reset_index(drop=True)

# Create X and y
X = df_merged.drop(columns=["Revenue"])
y = df_merged["Revenue"]

# Unique dates (months)
unique_dates = sorted(df_merged["Date"].unique())

# Settings
train_window = 36   # fixed training window
horizon = 6         # forecast horizon
step = 6            # move forward by 6 months each fold

splits = []

for i in range(train_window, len(unique_dates) - horizon + 1, step):
    train_dates = unique_dates[i - train_window:i]
    test_dates = unique_dates[i:i + horizon]

    train_mask = X["Date"].isin(train_dates)
    test_mask = X["Date"].isin(test_dates)

    X_train = X[train_mask].copy()
    y_train = y[train_mask].copy()

    X_test = X[test_mask].copy()
    y_test = y[test_mask].copy()

    splits.append((X_train, X_test, y_train, y_test))

# Show all folds
for fold, (X_train, X_test, y_train, y_test) in enumerate(splits, start=1):
    print(f"Fold {fold}")
    print("Train months:", X_train["Date"].min(), "to", X_train["Date"].max())
    print("Test months:", X_test["Date"].min(), "to", X_test["Date"].max())
    print("X_train shape:", X_train.shape)
    print("X_test shape:", X_test.shape)
    print("-" * 40)
# Out:
# Fold 1
# Train months: 2021-04-01 00:00:00 to 2024-03-01 00:00:00
# Test months: 2024-04-01 00:00:00 to 2024-09-01 00:00:00
# X_train shape: (4824, 80)
# X_test shape: (804, 80)
# ----------------------------------------

# %% [markdown]
# ### Correlation

# %%
# Keep only numeric variables
X_num = X.select_dtypes(include="number").copy()

# Compute Spearman correlation matrix
corr_matrix = X_num.corr(method="spearman")

# Plot heatmap
plt.figure(figsize=(12, 10))
sns.heatmap(corr_matrix, cmap=sns.light_palette("#5a6a26", as_cmap=True), center=0, square=True)
plt.title("Overall Spearman Correlation Matrix")
plt.tight_layout()
plt.show()

# %% [markdown]
# This function removes highly correlated predictors based on the absolute Spearman correlation computed. Features exceeding the specified threshold are dropped from both training and test data to reduce multicollinearity while preserving a leakage-free evaluation framework.

# %%
filtered_splits = []
drop_features_by_fold = []

for fold_id, (X_train, X_test, y_train, y_test) in enumerate(splits, start=1):
    X_train_filtered, X_test_filtered, to_drop = correlation_filter_train_test(
        X_train, X_test, threshold=0.8
    )

    filtered_splits.append((X_train_filtered, X_test_filtered, y_train, y_test))
    
    drop_features_by_fold.append({
        "fold": fold_id,
        "dropped_features": to_drop
    })

    print(f"Fold {fold_id}")
    print("Dropped features:", to_drop)
    print("X_train shape:", X_train_filtered.shape)
    print("X_test shape:", X_test_filtered.shape)
    print("-" * 40)
# Out:
# Fold 1
# Dropped features: ['China_GDP_from_Manufacturing', 'China_Interest_Rate', 'France_Core_Inflation_Rate', 'France_Exports', 'France_GDP_from_Construction', 'France_GDP_from_Manufacturing', 'France_Inflation_Rate', 'France_Interest_Rate', 'Germany_Core_Inflation_Rate', 'Germany_Exports', 'Germany_GDP', 'Germany_GDP_from_Construction', 'Germany_GDP_from_Manufacturing', 'Germany_Inflation_Rate', 'Germany_Interest_Rate', 'Italy_Core_Inflation_Rate', 'Italy_GDP', 'Italy_GDP_from_Construction', 'Italy_Industrial_Production', 'Italy_Inflation_Rate', 'Italy_Interest_Rate', 'Japan_Core_Inflation_Rate', 'Japan_GDP', 'Japan_GDP_from_Manufacturing', 'Japan_Inflation_Rate', 'Switzerland_Core_Inflation_Rate', 'Switzerland_GDP', 'Switzerland_Industrial_Production', 'Switzerland_Inflation_Rate', 'Switzerland_Interest_Rate', 'United_Kingdom_Core_Inflation_Rate', 'United_Kingdom_Exports', 'United_Kingdom_GDP', 'United_Kingdom_GDP_from_Construction', 'United_Kingdom_GDP_from_Manufacturing', 'United_Kingdom_Inflation_Rate', 'United_Kingdom_Interest_Rate', 'United_States_Core_Inflation_Rate', 'United_States_GDP', 'United_States_GDP_from_Construction', 'United_States_Industrial_Production', 'United_States_Inflation_Rate', 'United_States_Interest_Rate', 'United_States_Steel_Production']
# X_train shape: (4824, 36)
# X_test shape: (804, 36)
# ----------------------------------------

# %% [markdown]
# ### Feature Engeniring

# %% [markdown]
# Since CatBoost does not automatically generate time series predictors, additional
# features are created to capture temporal structure and historical patterns, such as
# calendar variables, lagged revenue values, and rolling statistics.

# %%
prepared_folds = prepare_all_folds_for_feature_selection(filtered_splits)
# Out:
# c:\Users\alano\Desktop\Mestrado\2- Semestre\Busines case\Siemens\Siemens git\alano testes\support.py:112: FutureWarning:
#
# The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#
# c:\Users\alano\Desktop\Mestrado\2- Semestre\Busines case\Siemens\Siemens git\alano testes\support.py:112: FutureWarning:
#
# The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#
# c:\Users\alano\Desktop\Mestrado\2- Semestre\Busines case\Siemens\Siemens git\alano testes\support.py:112: FutureWarning:
#
# The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#
# c:\Users\alano\Desktop\Mestrado\2- Semestre\Busines case\Siemens\Siemens git\alano testes\support.py:112: FutureWarning:
#
# The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#
# c:\Users\alano\Desktop\Mestrado\2- Semestre\Busines case\Siemens\Siemens git\alano testes\support.py:112: FutureWarning:
#
# The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#
# c:\Users\alano\Desktop\Mestrado\2- Semestre\Busines case\Siemens\Siemens git\alano testes\support.py:116: FutureWarning:
#
# The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#
# c:\Users\alano\Desktop\Mestrado\2- Semestre\Busines case\Siemens\Siemens git\alano testes\support.py:116: FutureWarning:
#
# The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#
# c:\Users\alano\Desktop\Mestrado\2- Semestre\Busines case\Siemens\Siemens git\alano testes\support.py:116: FutureWarning:
#
# The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#
# c:\Users\alano\Desktop\Mestrado\2- Semestre\Busines case\Siemens\Siemens git\alano testes\support.py:122: FutureWarning:
#
# The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#
# c:\Users\alano\Desktop\Mestrado\2- Semestre\Busines case\Siemens\Siemens git\alano testes\support.py:122: FutureWarning:
#
# The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#
# c:\Users\alano\Desktop\Mestrado\2- Semestre\Busines case\Siemens\Siemens git\alano testes\support.py:122: FutureWarning:
#
# The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.

# %%
for fold in prepared_folds:
    print(f"Fold {fold['fold_id']}")
    print("X_train:", fold["X_train"].shape)
    print("y_train:", fold["y_train"].shape)
    print("X_test_base:", fold["X_test_base"].shape)
    print("-" * 40)
# Out:
# Fold 1
# X_train: (3216, 65)
# y_train: (3216,)
# X_test_base: (804, 42)
# ----------------------------------------

# %% [markdown]
# ## Feature Selection

# %% [markdown]
# ### Mutual Information

# %% [markdown]
# Mutual Information is used to measure the relevance of each predictor with respect to
# the target variable. Because it captures non-linear as well as linear dependencies, it
# is a useful feature selection method for CatBoost, which is designed to model complex
# relationships in the data.

# %%
mi_filtered_results = select_features_by_mi(
    prepared_folds=prepared_folds,
    mi_threshold=0.0,
    top_k=None
)

# %%
for result in mi_filtered_results:
    print(f"Fold {result['fold_id']}")
    print("Selected features:", len(result["selected_features"]))
    print(result["selected_features"])
    print("-" * 40)
# Out:
# Fold 1
# Selected features: 45
# ['Business_Unit', 'Segment', 'Subsegment', 'series_id', 'China_GDP', 'Revenue_roll_mean_6', 'Revenue_dev_from_roll12', 'month', 'Revenue_roll_std_6', 'Switzerland_Industrial_Production_Mom', 'France_GDP', 'Revenue_lag_diff_1', 'Revenue_roll_std_12', 'Revenue_lag_2', 'Revenue_lag_6', 'Revenue_cv_12', 'Revenue_roll_mean_3', 'Germany_Steel_Production', 'China_Steel_Production', 'Revenue_cv_6', 'Revenue_rel_to_roll12', 'Italy_Exports', 'China_GDP_from_Construction', 'Revenue_roll_mean_12', 'Italy_GDP_from_Manufacturing', 'France_Industrial_Production', 'United_States_Exports', 'Japan_GDP_from_Construction', 'year', 'Japan_Industrial_Production', 'Revenue_lag_1', 'China_Core_Inflation_Rate', 'United_States_Industrial_Production_Mom', 'Revenue_lag_diff_12', 'China_Industrial_Production', 'United_States_GDP_from_Manufacturing', 'Italy_Industrial_Production_Mom', 'month_sin', 'Japan_Exports', 'United_Kingdom_Industrial_Production_Mom', 'Revenue_yoy_ratio', 'Switzerland_Exports', 'quarter', 'Revenue_yoy_diff', 'Germany_Industrial_Production_Mom']
# ----------------------------------------

# %% [markdown]
# Ranking das Features

# %%
# Combine MI rankings from all folds
mi_all = pd.concat([result["mi_ranking"].assign(fold=result["fold_id"])for result in mi_filtered_results],
    ignore_index=True)

# Average MI by feature across folds
mi_mean = (mi_all.groupby("feature", as_index=False)["mi_score"].mean().sort_values("mi_score", ascending=False))

# Optional: keep only top 30 features
top_n = 30
mi_mean_top = mi_mean.head(top_n)

# Plot
plt.figure(figsize=(10, 6))
sns.barplot(data=mi_mean_top, x="mi_score", y="feature")
plt.title("Mean Mutual Information Across Folds")
plt.xlabel("Mean MI Score")
plt.ylabel("Feature")
plt.tight_layout()
plt.show()

# %% [markdown]
# The heatmap shows the Mutual Information score of each predictor across folds.
# Features with higher and more consistent scores are considered more informative
# for the target variable, whereas predictors with near-zero or highly unstable
# scores appear to have limited or fold-dependent relevance.

# %%
# Optional: keep top features by average MI
top_n = 25
top_features = (mi_all.groupby("feature")["mi_score"].mean().sort_values(ascending=False).head(top_n).index)

mi_heatmap = mi_all[mi_all["feature"].isin(top_features)].pivot(index="feature",columns="fold",values="mi_score")

# Plot
plt.figure(figsize=(10, 7))
sns.heatmap(mi_heatmap, annot=True, fmt=".3f", cmap="YlOrRd")
plt.title("Mutual Information by Feature and Fold")
plt.xlabel("Fold")
plt.ylabel("Feature")
plt.tight_layout()
plt.show()

# %% [markdown]
# ### RecursiveByLossFunctionChange

# %% [markdown]
# The RecursiveByLossFunctionChange algorithm was adopted for feature selection because
# it represents the most appropriate compromise between accuracy and computational cost
# within CatBoost's recursive selection framework. While RecursiveByPredictionValuesChange
# is faster but less precise, and RecursiveByShapValues is more accurate but considerably
# more expensive, RecursiveByLossFunctionChange provides a robust and efficient criterion
# for repeated feature selection across validation folds.

# %%
catboost_fs_results = []

for fold in prepared_folds:
    fold_id = fold["fold_id"]
    X_train_fold = fold["X_train"].copy()
    y_train_fold = fold["y_train"].copy()
    cat_features = fold["cat_features"]

    selected_features, eliminated_features, raw_selection = catboost_select_features_fold(
        X_train=X_train_fold,
        y_train=y_train_fold,
        cat_features=cat_features,
        total_features_to_keep=20
    )

    catboost_fs_results.append({
        "fold_id": fold_id,
        "X_train_selected": X_train_fold[selected_features].copy(),
        "y_train": y_train_fold,
        "selected_features": selected_features,
        "eliminated_features": eliminated_features,
        "cat_features": [col for col in cat_features if col in selected_features],
        "raw_selection": raw_selection
    })

# %%
for result in catboost_fs_results:
    print(f"Fold {result['fold_id']}")
    print("Selected features:", result["selected_features"])
    print("Eliminated features:", result["eliminated_features"])
    print("-" * 50)
# Out:
# Fold 1
# Selected features: ['Business_Unit', 'Segment', 'Subsegment', 'series_id', 'Start_Period', 'Revenue_lag_2', 'Revenue_lag_3', 'Revenue_lag_6', 'Revenue_lag_12', 'Revenue_roll_mean_6', 'Revenue_roll_mean_12', 'Revenue_roll_std_12', 'Revenue_lag_diff_1', 'Revenue_cv_3', 'Revenue_cv_6', 'Revenue_cv_12', 'Revenue_zscore_12', 'trend_3_12', 'trend_6_12', 'Revenue_yoy_ratio']
# Eliminated features: ['Japan_Interest_Rate', 'year', 'quarter', 'China_GDP', 'Japan_GDP_from_Construction', 'France_GDP', 'China_Industrial_Production', 'month', 'United_States_GDP_from_Manufacturing', 'Italy_GDP_from_Manufacturing', 'China_GDP_from_Construction', 'Japan_Steel_Production', 'month_sin', 'time_idx', 'Germany_Steel_Production', 'month_cos', 'Germany_Industrial_Production', 'Switzerland_Industrial_Production_Mom', 'Italy_Industrial_Production_Mom', 'China_Core_Inflation_Rate', 'United_Kingdom_Industrial_Production', 'China_Inflation_Rate', 'China_Steel_Production', 'Japan_Exports', 'Japan_Industrial_Production_Mom', 'Germany_Industrial_Production_Mom', 'United_States_Exports', 'China_Industrial_Production_Mom', 'Italy_Exports', 'Japan_Industrial_Production', 'Switzerland_Exports', 'United_Kingdom_Industrial_Production_Mom', 'China_Exports', 'France_Industrial_Production_Mom', 'United_States_Industrial_Production_Mom', 'Revenue_yoy_diff', 'Revenue_rel_to_roll12', 'France_Industrial_Production', 'Revenue_lag_1', 'End_Period', 'Revenue_dev_from_roll12', 'Revenue_lag_diff_12', 'Revenue_roll_std_6', 'Revenue_roll_std_3', 'Revenue_roll_mean_3']
# --------------------------------------------------

# %%
# Build binary selection table
selection_rows = []

for result in catboost_fs_results:
    fold_id = result["fold_id"]
    for feature in result["selected_features"]:
        selection_rows.append({
            "fold_id": fold_id,
            "feature": feature,
            "selected": 1
        })

selection_df = pd.DataFrame(selection_rows)

# Pivot to feature x fold matrix
selection_matrix = selection_df.pivot_table(
    index="feature",
    columns="fold_id",
    values="selected",
    fill_value=0
)

# Optional: sort features by selection frequency
selection_matrix["total_selected"] = selection_matrix.sum(axis=1)
selection_matrix = selection_matrix.sort_values("total_selected", ascending=False)
selection_matrix = selection_matrix.drop(columns="total_selected")

# Plot heatmap
plt.figure(figsize=(10, max(6, len(selection_matrix) * 0.4)))
sns.heatmap(
    selection_matrix,
    annot=True,
    cmap="YlGnBu",
    cbar=False,
    linewidths=0.5,
    linecolor="white"
)
plt.title("Selected Features by Fold")
plt.xlabel("Fold")
plt.ylabel("Feature")
plt.tight_layout()
plt.show()

# %%
# Count how many times each feature was selected
feature_counts = {}

for result in catboost_fs_results:
    for feature in result["selected_features"]:
        feature_counts[feature] = feature_counts.get(feature, 0) + 1

freq_df = pd.DataFrame(
    list(feature_counts.items()),
    columns=["feature", "selection_count"]
).sort_values("selection_count", ascending=False)

# Plot
plt.figure(figsize=(10, max(6, len(freq_df) * 0.35)))
sns.barplot(
    data=freq_df,
    x="selection_count",
    y="feature"
)
plt.title("Feature Selection Frequency Across Folds")
plt.xlabel("Number of Folds Selected")
plt.ylabel("Feature")
plt.tight_layout()
plt.show()

# %% [markdown]
# ### Permutation importance

# %% [markdown]
# Permutation importance is used to assess the contribution of each selected feature to
# the predictive performance of the CatBoost model. For each fold, a baseline MAE is
# computed on the trained model, after which each predictor is permuted repeatedly to
# break its association with the target variable. The average increase in MAE induced
# by this permutation is taken as an estimate of feature importance, with larger values
# indicating greater predictive relevance.

# %%
permutation_results = []

for fold in prepared_folds:
    fold_id = fold["fold_id"]
    X_train = fold["X_train"].copy()
    y_train = fold["y_train"].copy()
    cat_features = fold["cat_features"]

    perm_df, trained_model, baseline_mae = manual_permutation_importance_fold(
        X_train=X_train,
        y_train=y_train,
        cat_features=cat_features,
        n_repeats=30,
        random_state=42
    )

    permutation_results.append({
        "fold_id": fold_id,
        "permutation_importance": perm_df,
        "baseline_mae": baseline_mae,
        "model": trained_model
    })

# %%
for result in permutation_results:
    print(f"Fold {result['fold_id']}")
    print("Baseline MAE:", result["baseline_mae"])
    print(result["permutation_importance"].head(10))
    print("-" * 40)
# Out:
# Fold 1
# Baseline MAE: 22351188.886753205
#                    feature  importance_mean  importance_std
# 0             Revenue_cv_6    587264.653485    20314.569059
# 1      Revenue_roll_mean_6    501068.332005    26432.927083
# 2       Revenue_lag_diff_1    471745.410920    34871.907656
# 3       Revenue_roll_std_3    457014.020976    27104.872205
# 4  Revenue_dev_from_roll12    443109.432184    14381.274107
# 5            Revenue_lag_3    442551.506261    24631.445572
# 6            Revenue_lag_6    428739.059093    19987.666021
# 7      Revenue_roll_std_12    422581.974838    14631.943527
# 8               trend_6_12    399567.848454    17404.155097
# 9            Revenue_lag_2    399342.395922    21168.884379
# ----------------------------------------

# %%
# Combine all folds
perm_all = pd.concat([result["permutation_importance"].assign(fold=result["fold_id"])for result in permutation_results],ignore_index=True)

# Aggregate mean importance across folds
perm_summary = (perm_all.groupby("feature", as_index=False)
    .agg(
        importance_mean=("importance_mean", "mean"),
        importance_std=("importance_mean", "std"))
    .sort_values("importance_mean", ascending=False))

# Optional: top N features
top_n = 15
perm_summary_top = perm_summary.head(top_n).sort_values("importance_mean", ascending=True)

plt.figure(figsize=(10, 6))
plt.barh(
    perm_summary_top["feature"],
    perm_summary_top["importance_mean"]
)
plt.title("Mean Permutation Importance Across Folds")
plt.xlabel("Mean Increase in MAE")
plt.ylabel("Feature")
plt.tight_layout()
plt.show()

# %%
# Combine all folds
perm_all = pd.concat(
    [
        result["permutation_importance"].assign(fold=result["fold_id"])
        for result in permutation_results
    ],
    ignore_index=True
)

# Select top features by average importance
top_n = 15
top_features = (
    perm_all.groupby("feature")["importance_mean"]
    .mean()
    .sort_values(ascending=False)
    .head(top_n)
    .index
)

heatmap_df = perm_all[perm_all["feature"].isin(top_features)].pivot(
    index="feature",
    columns="fold",
    values="importance_mean"
)

plt.figure(figsize=(10, 7))
sns.heatmap(heatmap_df, annot=True, fmt=".3f", cmap="YlOrRd")
plt.title("Permutation Importance by Feature and Fold")
plt.xlabel("Fold")
plt.ylabel("Feature")
plt.tight_layout()
plt.show()

# %% [markdown]
# ### Final Features

# %%
mi_summary_long = summarize_selected_features(
    results=mi_filtered_results,
    method_name="MI",
    feature_key="selected_features"
)

# %%
catboost_summary_long = summarize_selected_features(
    results=catboost_fs_results,
    method_name="CatBoost",
    feature_key="selected_features"
)

# %%
perm_rows = []

for result in permutation_results:
    fold_id = result["fold_id"]
    perm_df = result["permutation_importance"].copy()

    selected_features = perm_df.loc[
        perm_df["importance_mean"] > 0, "feature"
    ].tolist()

    for feature in selected_features:
        perm_rows.append({
            "fold_id": fold_id,
            "feature": feature,
            "method": "Permutation",
            "selected": 1
        })

perm_summary_long = pd.DataFrame(perm_rows)

# %%
all_fs_long = pd.concat(
    [mi_summary_long, catboost_summary_long, perm_summary_long],
    ignore_index=True
)

all_fs_long.head()
# Out:
#    fold_id        feature method  selected
# 0        1  Business_Unit     MI         1
# 1        1        Segment     MI         1
# 2        1     Subsegment     MI         1
# 3        1      series_id     MI         1
# 4        1      China_GDP     MI         1

# %%
n_folds = len(prepared_folds)

feature_method_summary = (
    all_fs_long.groupby(["feature", "method"], as_index=False)
    .agg(folds_selected=("fold_id", "nunique"))
)

feature_method_summary["selection_rate"] = (
    feature_method_summary["folds_selected"] / n_folds
)

feature_method_summary = feature_method_summary.sort_values(
    ["method", "selection_rate", "feature"],
    ascending=[True, False, True]
)

feature_method_summary
# Out:
#                                       feature       method  folds_selected  \
# 0                               Business_Unit     CatBoost               1
# 42                              Revenue_cv_12     CatBoost               1
# 45                               Revenue_cv_3     CatBoost               1
# 47                               Revenue_cv_6     CatBoost               1
# 54                             Revenue_lag_12     CatBoost               1
# 56                              Revenue_lag_2     CatBoost               1
# 59                              Revenue_lag_3     CatBoost               1
# 61                              Revenue_lag_6     CatBoost               1
# 64                         Revenue_lag_diff_1     CatBoost               1
# 71                       Revenue_roll_mean_12     CatBoost               1
# 76                        Revenue_roll_mean_6     CatBoost               1
# 79                        Revenue_roll_std_12     CatBoost               1
# 87                          Revenue_yoy_ratio     CatBoost               1
# 90                          Revenue_zscore_12     CatBoost               1
# 92                                    Segment     CatBoost               1
# 95                               Start_Period     CatBoost               1
# 97                                 Subsegment     CatBoost               1
# 120                                 series_id     CatBoost               1
# 124                                trend_3_12     CatBoost               1
# 126                                trend_6_12     CatBoost               1
# 1                               Business_Unit           MI               1
# 3                   China_Core_Inflation_Rate           MI               1
# 6                                   China_GDP           MI               1
# 8                 China_GDP_from_Construction           MI               1
# 10                China_Industrial_Production           MI               1
# 14                     China_Steel_Production           MI               1
# 17                                 France_GDP           MI               1
# 19               France_Industrial_Production           MI               1
# 23          Germany_Industrial_Production_Mom           MI               1
# 25                   Germany_Steel_Production           MI               1
# 27                              Italy_Exports           MI               1
# 29               Italy_GDP_from_Manufacturing           MI               1
# 31            Italy_Industrial_Production_Mom           MI               1
# 33                              Japan_Exports           MI               1
# 35                Japan_GDP_from_Construction           MI               1
# 37                Japan_Industrial_Production           MI               1
# 43                              Revenue_cv_12           MI               1
# 48                               Revenue_cv_6           MI               1
# 50                    Revenue_dev_from_roll12           MI               1
# 52                              Revenue_lag_1           MI               1
# 57                              Revenue_lag_2           MI               1
# 62                              Revenue_lag_6           MI               1
# 65                         Revenue_lag_diff_1           MI               1
# 67                        Revenue_lag_diff_12           MI               1
# 69                      Revenue_rel_to_roll12           MI               1
# 72                       Revenue_roll_mean_12           MI               1
# 74                        Revenue_roll_mean_3           MI               1
# 77                        Revenue_roll_mean_6           MI               1
# 80                        Revenue_roll_std_12           MI               1
# 83                         Revenue_roll_std_6           MI               1
# 85                           Revenue_yoy_diff           MI               1
# 88                          Revenue_yoy_ratio           MI               1
# 93                                    Segment           MI               1
# 98                                 Subsegment           MI               1
# 100                       Switzerland_Exports           MI               1
# 102     Switzerland_Industrial_Production_Mom           MI               1
# 105  United_Kingdom_Industrial_Production_Mom           MI               1
# 107                     United_States_Exports           MI               1
# 109      United_States_GDP_from_Manufacturing           MI               1
# 111   United_States_Industrial_Production_Mom           MI               1
# 113                                     month           MI               1
# 116                                 month_sin           MI               1
# 118                                   quarter           MI               1
# 121                                 series_id           MI               1
# 128                                      year           MI               1
# 2                               Business_Unit  Permutation               1
# 4                   China_Core_Inflation_Rate  Permutation               1
# 5                               China_Exports  Permutation               1
# 7                                   China_GDP  Permutation               1
# 9                 China_GDP_from_Construction  Permutation               1
# 11                China_Industrial_Production  Permutation               1
# 12            China_Industrial_Production_Mom  Permutation               1
# 13                       China_Inflation_Rate  Permutation               1
# 15                     China_Steel_Production  Permutation               1
# 16                                 End_Period  Permutation               1
# 18                                 France_GDP  Permutation               1
# 20               France_Industrial_Production  Permutation               1
# 21           France_Industrial_Production_Mom  Permutation               1
# 22              Germany_Industrial_Production  Permutation               1
# 24          Germany_Industrial_Production_Mom  Permutation               1
# 26                   Germany_Steel_Production  Permutation               1
# 28                              Italy_Exports  Permutation               1
# 30               Italy_GDP_from_Manufacturing  Permutation               1
# 32            Italy_Industrial_Production_Mom  Permutation               1
# 34                              Japan_Exports  Permutation               1
# 36                Japan_GDP_from_Construction  Permutation               1
# 38                Japan_Industrial_Production  Permutation               1
# 39            Japan_Industrial_Production_Mom  Permutation               1
# 40                        Japan_Interest_Rate  Permutation               1
# 41                     Japan_Steel_Production  Permutation               1
# 44                              Revenue_cv_12  Permutation               1
# 46                               Revenue_cv_3  Permutation               1
# 49                               Revenue_cv_6  Permutation               1
# 51                    Revenue_dev_from_roll12  Permutation               1
# 53                              Revenue_lag_1  Permutation               1
# 55                             Revenue_lag_12  Permutation               1
# 58                              Revenue_lag_2  Permutation               1
# 60                              Revenue_lag_3  Permutation               1
# 63                              Revenue_lag_6  Permutation               1
# 66                         Revenue_lag_diff_1  Permutation               1
# 68                        Revenue_lag_diff_12  Permutation               1
# 70                      Revenue_rel_to_roll12  Permutation               1
# 73                       Revenue_roll_mean_12  Permutation               1
# 75                        Revenue_roll_mean_3  Permutation               1
# 78                        Revenue_roll_mean_6  Permutation               1
# 81                        Revenue_roll_std_12  Permutation               1
# 82                         Revenue_roll_std_3  Permutation               1
# 84                         Revenue_roll_std_6  Permutation               1
# 86                           Revenue_yoy_diff  Permutation               1
# 89                          Revenue_yoy_ratio  Permutation               1
# 91                          Revenue_zscore_12  Permutation               1
# 94                                    Segment  Permutation               1
# 96                               Start_Period  Permutation               1
# 99                                 Subsegment  Permutation               1
# 101                       Switzerland_Exports  Permutation               1
# 103     Switzerland_Industrial_Production_Mom  Permutation               1
# 104      United_Kingdom_Industrial_Production  Permutation               1
# 106  United_Kingdom_Industrial_Production_Mom  Permutation               1
# 108                     United_States_Exports  Permutation               1
# 110      United_States_GDP_from_Manufacturing  Permutation               1
# 112   United_States_Industrial_Production_Mom  Permutation               1
# 114                                     month  Permutation               1
# 115                                 month_cos  Permutation               1
# 117                                 month_sin  Permutation               1
# 119                                   quarter  Permutation               1
# 122                                 series_id  Permutation               1
# 123                                  time_idx  Permutation               1
# 125                                trend_3_12  Permutation               1
# 127                                trend_6_12  Permutation               1
# 129                                      year  Permutation               1
#
#      selection_rate
# 0               1.0
# 42              1.0
# 45              1.0
# 47              1.0
# 54              1.0
# 56              1.0
# 59              1.0
# 61              1.0
# 64              1.0
# 71              1.0
# 76              1.0
# 79              1.0
# 87              1.0
# 90              1.0
# 92              1.0
# 95              1.0
# 97              1.0
# 120             1.0
# 124             1.0
# 126             1.0
# 1               1.0
# 3               1.0
# 6               1.0
# 8               1.0
# 10              1.0
# 14              1.0
# 17              1.0
# 19              1.0
# 23              1.0
# 25              1.0
# 27              1.0
# 29              1.0
# 31              1.0
# 33              1.0
# 35              1.0
# 37              1.0
# 43              1.0
# 48              1.0
# 50              1.0
# 52              1.0
# 57              1.0
# 62              1.0
# 65              1.0
# 67              1.0
# 69              1.0
# 72              1.0
# 74              1.0
# 77              1.0
# 80              1.0
# 83              1.0
# 85              1.0
# 88              1.0
# 93              1.0
# 98              1.0
# 100             1.0
# 102             1.0
# 105             1.0
# 107             1.0
# 109             1.0
# 111             1.0
# 113             1.0
# 116             1.0
# 118             1.0
# 121             1.0
# 128             1.0
# 2               1.0
# 4               1.0
# 5               1.0
# 7               1.0
# 9               1.0
# 11              1.0
# 12              1.0
# 13              1.0
# 15              1.0
# 16              1.0
# 18              1.0
# 20              1.0
# 21              1.0
# 22              1.0
# 24              1.0
# 26              1.0
# 28              1.0
# 30              1.0
# 32              1.0
# 34              1.0
# 36              1.0
# 38              1.0
# 39              1.0
# 40              1.0
# 41              1.0
# 44              1.0
# 46              1.0
# 49              1.0
# 51              1.0
# 53              1.0
# 55              1.0
# 58              1.0
# 60              1.0
# 63              1.0
# 66              1.0
# 68              1.0
# 70              1.0
# 73              1.0
# 75              1.0
# 78              1.0
# 81              1.0
# 82              1.0
# 84              1.0
# 86              1.0
# 89              1.0
# 91              1.0
# 94              1.0
# 96              1.0
# 99              1.0
# 101             1.0
# 103             1.0
# 104             1.0
# 106             1.0
# 108             1.0
# 110             1.0
# 112             1.0
# 114             1.0
# 115             1.0
# 117             1.0
# 119             1.0
# 122             1.0
# 123             1.0
# 125             1.0
# 127             1.0
# 129             1.0

# %%
feature_method_wide = feature_method_summary.pivot(
    index="feature",
    columns="method",
    values="selection_rate"
).fillna(0)

feature_method_wide = feature_method_wide.reset_index()

# %%
always_keep = ["Business_Unit", "Segment", "Subsegment", "series_id"]

consensus_df = feature_method_wide.copy()

# Ensure all method columns exist
for col in ["MI", "CatBoost", "Permutation"]:
    if col not in consensus_df.columns:
        consensus_df[col] = 0.0

consensus_df["methods_supporting"] = (
    (consensus_df["MI"] >= 2/3).astype(int) +
    (consensus_df["CatBoost"] >= 1/3).astype(int) +
    (consensus_df["Permutation"] >= 2/3).astype(int)
)

consensus_df["keep_recommended"] = (
    consensus_df["feature"].isin(always_keep) |
    (consensus_df["CatBoost"] >= 2/3) |
    (consensus_df["methods_supporting"] >= 3)
)

consensus_df = consensus_df.sort_values(
    ["keep_recommended", "CatBoost", "Permutation", "MI", "feature"],
    ascending=[False, False, False, False, True]
)

consensus_df
# Out:
# method                                   feature  CatBoost   MI  Permutation  \
# 0                                  Business_Unit       1.0  1.0          1.0
# 25                                 Revenue_cv_12       1.0  1.0          1.0
# 27                                  Revenue_cv_6       1.0  1.0          1.0
# 31                                 Revenue_lag_2       1.0  1.0          1.0
# 33                                 Revenue_lag_6       1.0  1.0          1.0
# 34                            Revenue_lag_diff_1       1.0  1.0          1.0
# 37                          Revenue_roll_mean_12       1.0  1.0          1.0
# 39                           Revenue_roll_mean_6       1.0  1.0          1.0
# 40                           Revenue_roll_std_12       1.0  1.0          1.0
# 44                             Revenue_yoy_ratio       1.0  1.0          1.0
# 46                                       Segment       1.0  1.0          1.0
# 48                                    Subsegment       1.0  1.0          1.0
# 60                                     series_id       1.0  1.0          1.0
# 26                                  Revenue_cv_3       1.0  0.0          1.0
# 30                                Revenue_lag_12       1.0  0.0          1.0
# 32                                 Revenue_lag_3       1.0  0.0          1.0
# 45                             Revenue_zscore_12       1.0  0.0          1.0
# 47                                  Start_Period       1.0  0.0          1.0
# 62                                    trend_3_12       1.0  0.0          1.0
# 63                                    trend_6_12       1.0  0.0          1.0
# 1                      China_Core_Inflation_Rate       0.0  1.0          1.0
# 3                                      China_GDP       0.0  1.0          1.0
# 4                    China_GDP_from_Construction       0.0  1.0          1.0
# 5                    China_Industrial_Production       0.0  1.0          1.0
# 8                         China_Steel_Production       0.0  1.0          1.0
# 10                                    France_GDP       0.0  1.0          1.0
# 11                  France_Industrial_Production       0.0  1.0          1.0
# 14             Germany_Industrial_Production_Mom       0.0  1.0          1.0
# 15                      Germany_Steel_Production       0.0  1.0          1.0
# 16                                 Italy_Exports       0.0  1.0          1.0
# 17                  Italy_GDP_from_Manufacturing       0.0  1.0          1.0
# 18               Italy_Industrial_Production_Mom       0.0  1.0          1.0
# 19                                 Japan_Exports       0.0  1.0          1.0
# 20                   Japan_GDP_from_Construction       0.0  1.0          1.0
# 21                   Japan_Industrial_Production       0.0  1.0          1.0
# 28                       Revenue_dev_from_roll12       0.0  1.0          1.0
# 29                                 Revenue_lag_1       0.0  1.0          1.0
# 35                           Revenue_lag_diff_12       0.0  1.0          1.0
# 36                         Revenue_rel_to_roll12       0.0  1.0          1.0
# 38                           Revenue_roll_mean_3       0.0  1.0          1.0
# 42                            Revenue_roll_std_6       0.0  1.0          1.0
# 43                              Revenue_yoy_diff       0.0  1.0          1.0
# 49                           Switzerland_Exports       0.0  1.0          1.0
# 50         Switzerland_Industrial_Production_Mom       0.0  1.0          1.0
# 52      United_Kingdom_Industrial_Production_Mom       0.0  1.0          1.0
# 53                         United_States_Exports       0.0  1.0          1.0
# 54          United_States_GDP_from_Manufacturing       0.0  1.0          1.0
# 55       United_States_Industrial_Production_Mom       0.0  1.0          1.0
# 56                                         month       0.0  1.0          1.0
# 58                                     month_sin       0.0  1.0          1.0
# 59                                       quarter       0.0  1.0          1.0
# 64                                          year       0.0  1.0          1.0
# 2                                  China_Exports       0.0  0.0          1.0
# 6                China_Industrial_Production_Mom       0.0  0.0          1.0
# 7                           China_Inflation_Rate       0.0  0.0          1.0
# 9                                     End_Period       0.0  0.0          1.0
# 12              France_Industrial_Production_Mom       0.0  0.0          1.0
# 13                 Germany_Industrial_Production       0.0  0.0          1.0
# 22               Japan_Industrial_Production_Mom       0.0  0.0          1.0
# 23                           Japan_Interest_Rate       0.0  0.0          1.0
# 24                        Japan_Steel_Production       0.0  0.0          1.0
# 41                            Revenue_roll_std_3       0.0  0.0          1.0
# 51          United_Kingdom_Industrial_Production       0.0  0.0          1.0
# 57                                     month_cos       0.0  0.0          1.0
# 61                                      time_idx       0.0  0.0          1.0
#
# method  methods_supporting  keep_recommended
# 0                        3              True
# 25                       3              True
# 27                       3              True
# 31                       3              True
# 33                       3              True
# 34                       3              True
# 37                       3              True
# 39                       3              True
# 40                       3              True
# 44                       3              True
# 46                       3              True
# 48                       3              True
# 60                       3              True
# 26                       2              True
# 30                       2              True
# 32                       2              True
# 45                       2              True
# 47                       2              True
# 62                       2              True
# 63                       2              True
# 1                        2             False
# 3                        2             False
# 4                        2             False
# 5                        2             False
# 8                        2             False
# 10                       2             False
# 11                       2             False
# 14                       2             False
# 15                       2             False
# 16                       2             False
# 17                       2             False
# 18                       2             False
# 19                       2             False
# 20                       2             False
# 21                       2             False
# 28                       2             False
# 29                       2             False
# 35                       2             False
# 36                       2             False
# 38                       2             False
# 42                       2             False
# 43                       2             False
# 49                       2             False
# 50                       2             False
# 52                       2             False
# 53                       2             False
# 54                       2             False
# 55                       2             False
# 56                       2             False
# 58                       2             False
# 59                       2             False
# 64                       2             False
# 2                        1             False
# 6                        1             False
# 7                        1             False
# 9                        1             False
# 12                       1             False
# 13                       1             False
# 22                       1             False
# 23                       1             False
# 24                       1             False
# 41                       1             False
# 51                       1             False
# 57                       1             False
# 61                       1             False

# %%
features_methods_gt2 = consensus_df.loc[
    consensus_df["methods_supporting"] > 1,
    "feature"
].tolist()

len(features_methods_gt2)
# Out:
# 52

# %% [markdown]
# ## MODEL

# %% [markdown]
# ### CatBoost

# %% [markdown]
# This procedure implements recursive multi-step forecasting with CatBoost. The model
# is trained on each fold, test features are generated from the available history only,
# and predictions are iteratively fed back into the series to evaluate forecasting
# performance over the 6-month horizon.

# %%
model_folds = []

for fold in prepared_folds:
    fold_id = fold["fold_id"]

    X_train_full = fold["X_train"].copy()
    y_train = fold["y_train"].copy()

    # Keep only selected features that exist in this fold
    selected_features = [col for col in features_methods_gt2 if col in X_train_full.columns]

    X_train_model = X_train_full[selected_features].copy()

    # Keep only categorical features that are still present
    cat_features = [col for col in fold["cat_features"] if col in selected_features]

    model_folds.append({
        "fold_id": fold_id,
        "X_train_model": X_train_model,
        "y_train": y_train,
        "selected_features": selected_features,
        "cat_features": cat_features
    })

# %%
metrics_df, fold_predictions = evaluate_folds(splits, model_folds)
metrics_df
# Out:
#    fold_id       row_mae      row_rmse   monthly_mae  monthly_rmse  \
# 0        1  3.899526e+07  5.730739e+07  1.924686e+09  2.531053e+09
#
#    true_6m_total  pred_6m_total  abs_error_6m_total  n_selected_features
# 0    24311515926   3.585963e+10        1.154812e+10                   52

# %%
metrics_df.mean(numeric_only=True)
# Out:
# fold_id                1.000000e+00
# row_mae                3.899526e+07
# row_rmse               5.730739e+07
# monthly_mae            1.924686e+09
# monthly_rmse           2.531053e+09
# true_6m_total          2.431152e+10
# pred_6m_total          3.585963e+10
# abs_error_6m_total     1.154812e+10
# n_selected_features    5.200000e+01
# dtype: float64

# %%
print("Average row MAE:", metrics_df["row_mae"].mean())
print("Average row RMSE:", metrics_df["row_rmse"].mean())

print("Average monthly MAE:", metrics_df["monthly_mae"].mean())
print("Average monthly RMSE:", metrics_df["monthly_rmse"].mean())

print("Average 6M absolute error:", metrics_df["abs_error_6m_total"].mean())
# Out:
# Average row MAE: 38995263.767377526
# Average row RMSE: 57307387.32884994
# Average monthly MAE: 1924686223.872347
# Average monthly RMSE: 2531052709.2174163
# Average 6M absolute error: 11548117343.234085

# %% [markdown]
# ## Hyperparameters

# %%
param_grid = {
    "depth": [4, 6, 8],
    "learning_rate": [0.01, 0.03, 0.05],
    "iterations": [300, 500, 800],
    "l2_leaf_reg": [3, 5, 7]
}

# %%
param_combinations = generate_param_combinations(param_grid)

# %%
"""results_df = test_catboost_hyperparameters_middle_out(
    splits=filtered_splits,
    selected_features=features_methods_gt2,
    param_combinations=param_combinations,
    ranking_metric="monthly_mae"
)

results_df.head(10)"""
# Out:
# 'results_df = test_catboost_hyperparameters_middle_out(\n    splits=filtered_splits,\n    selected_features=features_methods_gt2,\n    param_combinations=param_combinations,\n    ranking_metric="monthly_mae"\n)\n\nresults_df.head(10)'

# %%
"""best_row = results_df.iloc[0]
best_params = best_row["params"]

print(best_params)
"""
# Out:
# 'best_row = results_df.iloc[0]\nbest_params = best_row["params"]\n\nprint(best_params)\n'

# %%
best_params = {'depth': 8, 'learning_rate': 0.01, 'iterations': 300, 'l2_leaf_reg': 5}

# %% [markdown]
# ### Catboost com hierarquia coerente

# %%
fold_metrics = []
fold_outputs = []

for fold_id, fold_split in enumerate(splits, start=1):
    model, middle_pred, top_pred, bottom_eval, monthly_bottom, metrics = run_middle_out_fold(
        fold_split=fold_split,
        selected_features=features_methods_gt2,
        model_params=best_params
    )

    fold_metrics.append({
        "fold_id": fold_id,
        **metrics
    })

    fold_outputs.append({
        "fold_id": fold_id,
        "middle_pred": middle_pred,
        "top_pred": top_pred,
        "bottom_eval": bottom_eval,
        "monthly_bottom": monthly_bottom,
        "model": model
    })

metrics_df = pd.DataFrame(fold_metrics)
metrics_df
# Out:
# c:\Users\alano\Desktop\Mestrado\2- Semestre\Busines case\Siemens\Siemens git\alano testes\support.py:112: FutureWarning:
#
# The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#
# c:\Users\alano\Desktop\Mestrado\2- Semestre\Busines case\Siemens\Siemens git\alano testes\support.py:112: FutureWarning:
#
# The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#
# c:\Users\alano\Desktop\Mestrado\2- Semestre\Busines case\Siemens\Siemens git\alano testes\support.py:112: FutureWarning:
#
# The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#
# c:\Users\alano\Desktop\Mestrado\2- Semestre\Busines case\Siemens\Siemens git\alano testes\support.py:112: FutureWarning:
#
# The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#
# c:\Users\alano\Desktop\Mestrado\2- Semestre\Busines case\Siemens\Siemens git\alano testes\support.py:112: FutureWarning:
#
# The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#
# c:\Users\alano\Desktop\Mestrado\2- Semestre\Busines case\Siemens\Siemens git\alano testes\support.py:116: FutureWarning:
#
# The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#
# c:\Users\alano\Desktop\Mestrado\2- Semestre\Busines case\Siemens\Siemens git\alano testes\support.py:116: FutureWarning:
#
# The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#
# c:\Users\alano\Desktop\Mestrado\2- Semestre\Busines case\Siemens\Siemens git\alano testes\support.py:116: FutureWarning:
#
# The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#
# c:\Users\alano\Desktop\Mestrado\2- Semestre\Busines case\Siemens\Siemens git\alano testes\support.py:122: FutureWarning:
#
# The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#
# c:\Users\alano\Desktop\Mestrado\2- Semestre\Busines case\Siemens\Siemens git\alano testes\support.py:122: FutureWarning:
#
# The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#
# c:\Users\alano\Desktop\Mestrado\2- Semestre\Busines case\Siemens\Siemens git\alano testes\support.py:122: FutureWarning:
#
# The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#    fold_id    bottom_mae   bottom_rmse   monthly_mae  monthly_rmse  \
# 0        1  1.213301e+07  2.532586e+07  2.108001e+08  2.878347e+08
#
#    true_6m_total  pred_6m_total  abs_error_6m_total
# 0    24311515926   2.322460e+10        1.086913e+09

# %%
metrics_df["error_pct_6m_total"] = (
    metrics_df["abs_error_6m_total"] / metrics_df["true_6m_total"] * 100
).round(2)
metrics_df
# Out:
#    fold_id    bottom_mae   bottom_rmse   monthly_mae  monthly_rmse  \
# 0        1  1.213301e+07  2.532586e+07  2.108001e+08  2.878347e+08
#
#    true_6m_total  pred_6m_total  abs_error_6m_total  error_pct_6m_total
# 0    24311515926   2.322460e+10        1.086913e+09                4.47

# %% [markdown]
# ## SHAP Analysis

# %%
fold_idx = 0

model = fold_predictions[fold_idx]["model"]
X_train_model = model_folds[fold_idx]["X_train_model"].copy()

# %%
explainer = shap.TreeExplainer(model)
shap_values = explainer.shap_values(X_train_model)

# %%
shap.summary_plot(shap_values, X_train_model)

# %% [markdown]
# In the plots above, we can see that the features 'series_id', 'Revenue_roll_std_12' and 'Subsegment' were the most important features in predicting the revenue.

# %% [markdown]
# **SHAP Analysis:** SHAP explains how CatBoost makes each individual decision.
#
# The **bar chart** (global importance) shows the features that most influence predictions on average.
#
# The **beeswarm plot** is richer — each dot is a client. Dots to the right (positive SHAP) increase the revenue; to the left they decrease it. The color indicates the feature value (red=high, blue=low). E.g.: red dots on the right for revenue_lag_3 indicates that in the previous 3 months the revenue has high so it tends to predict to have a higher probability higher revenue in the month predicted — an actionable insight.

# %%
shap.summary_plot(shap_values, X_train_model, plot_type="bar")

# %%
shap_df = pd.DataFrame(
    shap_values,
    columns=X_train_model.columns
)

shap_df.head()
# Out:
#    Business_Unit  Revenue_cv_12  Revenue_cv_6  Revenue_lag_2  Revenue_lag_6  \
# 0  -1.134645e+06  -1.069882e+06  8.352305e+05  -5.810459e+05  -1.825764e+06
# 1  -1.287866e+06   5.482093e+05  1.169466e+06   2.984337e+06  -2.183533e+05
# 2  -1.265082e+06  -9.120416e+04  1.434194e+06  -4.301733e+05  -2.965328e+06
# 3  -8.435823e+05  -3.992209e+06  9.970431e+05  -1.972537e+05   7.832381e+06
# 4  -1.785554e+06  -1.671564e+06 -9.717328e+05   3.049906e+05  -5.059848e+05
#
#    Revenue_lag_diff_1  Revenue_roll_mean_12  Revenue_roll_mean_6  \
# 0       -1.228520e+06         -9.926048e+05         5.001074e+05
# 1        1.144960e+06         -1.427523e+06         1.566500e+06
# 2       -4.173617e+05         -2.184567e+06         2.330520e+06
# 3       -1.939744e+05         -1.999240e+06         3.251389e+06
# 4        9.352715e+05          1.697664e+06        -2.893735e+05
#
#    Revenue_roll_std_12  Revenue_yoy_ratio  ...  Switzerland_Exports  \
# 0         6.189977e+05      -2.805369e+06  ...         3.108713e+04
# 1         1.626481e+06       1.188915e+06  ...        -3.514053e+05
# 2         1.803746e+06       1.117638e+06  ...        -1.205918e+05
# 3         2.117944e+06       5.145860e+05  ...         2.429116e+06
# 4         2.377252e+06      -1.550225e+06  ...        -4.311071e+05
#
#    Switzerland_Industrial_Production_Mom  \
# 0                         -813603.954360
# 1                         -741490.768076
# 2                          503276.686969
# 3                          319001.457727
# 4                          402578.347674
#
#    United_Kingdom_Industrial_Production_Mom  United_States_Exports  \
# 0                             -21185.797799           26695.435330
# 1                             194900.571155           42433.079031
# 2                            -325274.781219          -35434.490078
# 3                             182564.083074          359717.031802
# 4                            -542010.146830          476456.961075
#
#    United_States_GDP_from_Manufacturing  \
# 0                        -389094.251940
# 1                        -606519.091268
# 2                         217492.109148
# 3                         214939.007343
# 4                         425916.364940
#
#    United_States_Industrial_Production_Mom          month      month_sin  \
# 0                            539731.839166  259849.650110  155758.445725
# 1                           -159825.487321  129415.699611 -151905.965916
# 2                            -12824.385553  161820.833461    7090.035224
# 3                            709414.995945   84849.844374  203138.982717
# 4                            476318.412244   47590.249556  -42145.066886
#
#          quarter           year
# 0  182796.619182 -161357.298934
# 1 -107032.794670  -80681.231694
# 2 -154933.243429  -77996.969007
# 3  144202.522363  -82770.226645
# 4   85861.121166 -154653.414817
#
# [5 rows x 52 columns]

# %%
shap_importance = pd.DataFrame({
    "feature": X_train_model.columns,
    "mean_abs_shap": np.abs(shap_values).mean(axis=0)
}).sort_values("mean_abs_shap", ascending=False)

shap_importance
# Out:
#                                      feature  mean_abs_shap
# 12                                 series_id   2.400603e+06
# 8                        Revenue_roll_std_12   2.400498e+06
# 1                              Revenue_cv_12   2.160818e+06
# 7                        Revenue_roll_mean_6   1.878590e+06
# 11                                Subsegment   1.781807e+06
# 16                         Revenue_zscore_12   1.740658e+06
# 9                          Revenue_yoy_ratio   1.715724e+06
# 2                               Revenue_cv_6   1.621568e+06
# 19                                trend_6_12   1.613687e+06
# 5                         Revenue_lag_diff_1   1.594533e+06
# 4                              Revenue_lag_6   1.573074e+06
# 14                            Revenue_lag_12   1.571549e+06
# 18                                trend_3_12   1.545576e+06
# 6                       Revenue_roll_mean_12   1.483035e+06
# 40                        Revenue_roll_std_6   1.389211e+06
# 15                             Revenue_lag_3   1.363552e+06
# 3                              Revenue_lag_2   1.295166e+06
# 13                              Revenue_cv_3   1.272006e+06
# 0                              Business_Unit   1.208807e+06
# 39                       Revenue_roll_mean_3   1.073825e+06
# 38                     Revenue_rel_to_roll12   9.906834e+05
# 17                              Start_Period   8.584437e+05
# 10                                   Segment   8.580579e+05
# 35                   Revenue_dev_from_roll12   8.408100e+05
# 47   United_States_Industrial_Production_Mom   7.825851e+05
# 36                             Revenue_lag_1   7.810205e+05
# 37                       Revenue_lag_diff_12   6.848643e+05
# 26              France_Industrial_Production   6.322142e+05
# 43     Switzerland_Industrial_Production_Mom   6.073545e+05
# 42                       Switzerland_Exports   5.705827e+05
# 41                          Revenue_yoy_diff   5.371140e+05
# 31           Italy_Industrial_Production_Mom   4.829738e+05
# 29                             Italy_Exports   4.542053e+05
# 44  United_Kingdom_Industrial_Production_Mom   4.382987e+05
# 46      United_States_GDP_from_Manufacturing   4.222506e+05
# 32                             Japan_Exports   3.820023e+05
# 22               China_GDP_from_Construction   3.584215e+05
# 23               China_Industrial_Production   3.222306e+05
# 34               Japan_Industrial_Production   3.037345e+05
# 30              Italy_GDP_from_Manufacturing   2.928667e+05
# 45                     United_States_Exports   2.883094e+05
# 49                                 month_sin   2.822033e+05
# 27         Germany_Industrial_Production_Mom   2.764352e+05
# 48                                     month   2.570606e+05
# 28                  Germany_Steel_Production   2.288043e+05
# 50                                   quarter   2.235318e+05
# 20                 China_Core_Inflation_Rate   2.206080e+05
# 24                    China_Steel_Production   2.189293e+05
# 25                                France_GDP   1.097397e+05
# 33               Japan_GDP_from_Construction   1.021288e+05
# 21                                 China_GDP   8.647926e+04
# 51                                      year   8.487177e+04

# %% [markdown]
# ## PROPHET

# %%
#pip install prophet

# %%
# Copy original data
df_prophet = df_merged.copy()

# Keep date as datetime
df_prophet["Date"] = pd.to_datetime(df_prophet["Date"])

# Create middle-out series id
df_prophet["unique_id"] = (
    df_prophet["Business_Unit"].astype(str) + "__" +
    df_prophet["Segment"].astype(str)
)

# Aggregate revenue by series and month
df_prophet = (
    df_prophet.groupby(["unique_id", "Business_Unit", "Segment", "Date"], as_index=False)["Revenue"]
    .sum()
    .sort_values(["unique_id", "Date"])
    .reset_index(drop=True)
)

df_prophet.head()
# Out:
#           unique_id Business_Unit   Segment       Date  Revenue
# 0  SSI027__SSI02710        SSI027  SSI02710 2021-04-01  -390277
# 1  SSI027__SSI02710        SSI027  SSI02710 2021-05-01      334
# 2  SSI027__SSI02710        SSI027  SSI02710 2021-06-01      334
# 3  SSI027__SSI02710        SSI027  SSI02710 2021-07-01  1811758
# 4  SSI027__SSI02710        SSI027  SSI02710 2021-08-01    80112

# %%
# Get unique dates
all_dates = sorted(df_prophet["Date"].unique())

# Last 6 months as test
test_dates = all_dates[-6:]
train_dates = all_dates[:-6]

df_train = df_prophet[df_prophet["Date"].isin(train_dates)].copy()
df_test = df_prophet[df_prophet["Date"].isin(test_dates)].copy()

# %%
prophet_forecasts = []

for unique_id in df_train["unique_id"].unique():
    train_series = df_train[df_train["unique_id"] == unique_id].copy()

    # Prophet format
    prophet_train = train_series.rename(columns={
        "Date": "ds",
        "Revenue": "y"
    })[["ds", "y"]]

    # Fit model
    model = Prophet(
        yearly_seasonality=True,
        weekly_seasonality=False,
        daily_seasonality=False
    )
    model.fit(prophet_train)

    # Forecast next 6 months
    future = model.make_future_dataframe(periods=6, freq="MS", include_history=False)
    forecast = model.predict(future)

    forecast["unique_id"] = unique_id

    prophet_forecasts.append(
        forecast[["unique_id", "ds", "yhat", "yhat_lower", "yhat_upper"]]
    )

fcst_df = pd.concat(prophet_forecasts, ignore_index=True)
fcst_df.head()
# Out:
# 22:26:42 - cmdstanpy - INFO - Chain [1] start processing
# 22:26:43 - cmdstanpy - INFO - Chain [1] done processing
# 22:26:43 - cmdstanpy - INFO - Chain [1] start processing
# 22:26:43 - cmdstanpy - INFO - Chain [1] done processing
# 22:26:43 - cmdstanpy - INFO - Chain [1] start processing
# 22:26:43 - cmdstanpy - INFO - Chain [1] done processing
# 22:26:43 - cmdstanpy - INFO - Chain [1] start processing
# 22:26:44 - cmdstanpy - INFO - Chain [1] done processing
# 22:26:44 - cmdstanpy - INFO - Chain [1] start processing
# 22:26:44 - cmdstanpy - INFO - Chain [1] done processing
# 22:26:45 - cmdstanpy - INFO - Chain [1] start processing
# 22:26:45 - cmdstanpy - INFO - Chain [1] done processing
# 22:26:46 - cmdstanpy - INFO - Chain [1] start processing
# 22:26:46 - cmdstanpy - INFO - Chain [1] done processing
# 22:26:48 - cmdstanpy - INFO - Chain [1] start processing
# 22:26:48 - cmdstanpy - INFO - Chain [1] done processing
# 22:26:48 - cmdstanpy - INFO - Chain [1] start processing
# 22:26:49 - cmdstanpy - INFO - Chain [1] done processing
# 22:26:49 - cmdstanpy - INFO - Chain [1] start processing
# 22:26:49 - cmdstanpy - INFO - Chain [1] done processing
# 22:26:50 - cmdstanpy - INFO - Chain [1] start processing
# 22:26:50 - cmdstanpy - INFO - Chain [1] done processing
# 22:26:51 - cmdstanpy - INFO - Chain [1] start processing
# 22:26:51 - cmdstanpy - INFO - Chain [1] done processing
# 22:26:51 - cmdstanpy - INFO - Chain [1] start processing
# 22:26:51 - cmdstanpy - INFO - Chain [1] done processing
# 22:26:52 - cmdstanpy - INFO - Chain [1] start processing
# 22:26:52 - cmdstanpy - INFO - Chain [1] done processing
# 22:26:52 - cmdstanpy - INFO - Chain [1] start processing
# 22:26:53 - cmdstanpy - INFO - Chain [1] done processing
# 22:26:53 - cmdstanpy - INFO - Chain [1] start processing
# 22:26:53 - cmdstanpy - INFO - Chain [1] done processing
# 22:26:54 - cmdstanpy - INFO - Chain [1] start processing
# 22:26:54 - cmdstanpy - INFO - Chain [1] done processing
# 22:26:54 - cmdstanpy - INFO - Chain [1] start processing
# 22:26:55 - cmdstanpy - INFO - Chain [1] done processing
# 22:26:55 - cmdstanpy - INFO - Chain [1] start processing
# 22:26:55 - cmdstanpy - INFO - Chain [1] done processing
#           unique_id         ds          yhat    yhat_lower    yhat_upper
# 0  SSI027__SSI02710 2024-04-01 -3.630911e+05 -7.864276e+05  6.732847e+04
# 1  SSI027__SSI02710 2024-05-01 -1.153384e+05 -5.356381e+05  3.026716e+05
# 2  SSI027__SSI02710 2024-06-01 -1.744429e+05 -6.080352e+05  2.650625e+05
# 3  SSI027__SSI02710 2024-07-01  2.403577e+06  1.973418e+06  2.836021e+06
# 4  SSI027__SSI02710 2024-08-01  4.934956e+05  4.202044e+04  9.156561e+05

# %%
# Prepare test in Prophet format
df_test_eval = df_test.rename(columns={
    "Date": "ds",
    "Revenue": "y"
})[["unique_id", "ds", "y"]].copy()

# Merge forecast with actuals
eval_df = df_test_eval.merge(
    fcst_df,
    on=["unique_id", "ds"],
    how="left"
)

# Row-level metrics
row_mae = mean_absolute_error(eval_df["y"], eval_df["yhat"])
row_rmse = np.sqrt(mean_squared_error(eval_df["y"], eval_df["yhat"]))

print("Row MAE:", row_mae)
print("Row RMSE:", row_rmse)
# Out:
# Row MAE: 13057193.169246329
# Row RMSE: 31351263.527187508

# %%
monthly_eval = (
    eval_df.groupby("ds", as_index=False)[["y", "yhat"]]
    .sum()
    .sort_values("ds")
)

monthly_mae = mean_absolute_error(monthly_eval["y"], monthly_eval["yhat"])
monthly_rmse = np.sqrt(mean_squared_error(monthly_eval["y"], monthly_eval["yhat"]))

print("Monthly MAE:", monthly_mae)
print("Monthly RMSE:", monthly_rmse)
# Out:
# Monthly MAE: 181537062.51378497
# Monthly RMSE: 213000635.87534472

# %%
# Row-level percentage errors
eval_df["pct_error"] = np.where(
    eval_df["y"] != 0,
    (eval_df["yhat"] - eval_df["y"]) / eval_df["y"] * 100,
    np.nan
)

eval_df["abs_pct_error"] = np.where(
    eval_df["y"] != 0,
    np.abs(eval_df["yhat"] - eval_df["y"]) / np.abs(eval_df["y"]) * 100,
    np.nan
)

row_mape = eval_df["abs_pct_error"].mean()

# Monthly aggregated percentage errors
monthly_eval["pct_error"] = np.where(
    monthly_eval["y"] != 0,
    (monthly_eval["yhat"] - monthly_eval["y"]) / monthly_eval["y"] * 100,
    np.nan
)

monthly_eval["abs_pct_error"] = np.where(
    monthly_eval["y"] != 0,
    np.abs(monthly_eval["yhat"] - monthly_eval["y"]) / np.abs(monthly_eval["y"]) * 100,
    np.nan
)

monthly_mape = monthly_eval["abs_pct_error"].mean()

# 6-month total percentage error
true_6m_total = monthly_eval["y"].sum()
pred_6m_total = monthly_eval["yhat"].sum()
abs_error_6m_total = abs(pred_6m_total - true_6m_total)
error_pct_6m_total = abs_error_6m_total / true_6m_total * 100

print("Row MAPE (%):", row_mape.round(2))
print("Monthly MAPE (%):", monthly_mape.round(2))
print("6-month total error (%):", error_pct_6m_total.round(2))
# Out:
# Row MAPE (%): 33.28
# Monthly MAPE (%): 4.46
# 6-month total error (%): 1.85
